# %% [markdown]
# #  PyBIDS
# ## A Python API for working with BIDS datasets
#
# **Author:** Monika Doerig
#
# **Date:** 4 June 2025
#
# ### Citation and Resources:
#
# #### Data from OpenNeuro
# - Gorgolewski KJ and Storkey A and Bastin ME and Whittle IR and Wardlaw JM and Pernet CR (2022). A test-retest fMRI dataset for motor, language and spatial attention functions. OpenNeuro. [Dataset] doi: doi[10.18112/openneuro.ds000114.v1.0.2](https://doi.org/10.18112/openneuro.ds000114.v1.0.2)
#
# #### Tools included in this workflow
# **pyBIDS**:
#
# - Yarkoni et al., (2019). PyBIDS: Python tools for BIDS datasets. Journal of Open Source Software, 4(40), 1294, [https://doi.org/10.21105/joss.01294](https://doi.org/10.21105/joss.01294)
#
# - Yarkoni, T., Markiewicz, C. J., de la Vega, A., Gorgolewski, K. J., Salo, T., Gau, R., Halchenko, Y. O., Papadopoulos Orfanos, D., Esteban, O., McNamara, Q., DeStasio, K., Poline, J.-B., Johnson, H., Kalenkovich, E., Petrov, D., Nielson, D. M., James Kent, Kent, J. D., Appelhoff, S., … pierre-nedelec. (2024). PyBIDS: Python tools for BIDS datasets (0.18.1). Zenodo. [https://doi.org/10.5281/zenodo.14285569](https://doi.org/10.5281/zenodo.14285569)
#
# #### Educational resources
# - This example is highly inspired by the [pybids documentation](https://bids-standard.github.io/pybids/index.html)

# %% [markdown]
# ## Installation
#
# PyBIDS simplifies the process of querying, summarizing, and managing data for neuroimaging researchers using the BIDS standard. Several Python packages for neuroimaging analysis—such as Nipype and Nilearn—are designed to integrate seamlessly with BIDS-formatted datasets

# %%
# %%capture
! pip install pybids

# %% [markdown]
# ## Data download

# %%
PATTERN = "sub-0[1-5]"
! datalad install https://github.com/OpenNeuroDatasets/ds000114.git 
! cd ds000114 && datalad get $PATTERN
# Out:
# Cloning:   0%|                             | 0.00/2.00 [00:00<?, ? candidates/s]
# Enumerating: 0.00 Objects [00:00, ? Objects/s]
#
# Counting:   0%|                                | 0.00/820 [00:00<?, ? Objects/s]
#
# Compressing:   0%|                             | 0.00/616 [00:00<?, ? Objects/s]
#
# Receiving:   0%|                             | 0.00/2.17k [00:00<?, ? Objects/s]
#
# Resolving:   0%|                                | 0.00/147 [00:00<?, ? Deltas/s]
# [INFO   ] scanning for unlocked files (this may take some time)
# [INFO   ] Remote origin not usable by git-annex; setting annex-ignore
# [INFO   ] access to 1 dataset sibling s3-PRIVATE not auto-enabled, enable with:
# | 		datalad siblings -d "/home/jovyan/Git_repositories/example-notebooks/books/workflows/ds000114" enable -s s3-PRIVATE
# install(ok): /home/jovyan/Git_repositories/example-notebooks/books/workflows/ds000114 (dataset)
# Total:   0%|                                   | 0.00/2.17G [00:00<?, ? Bytes/s]
# Get sub-02/s .. t_T1w.nii.gz:   0%|            | 0.00/8.90M [00:00<?, ? Bytes/s]
# Get sub-02/s .. t_T1w.nii.gz:   2%|     | 139k/8.90M [00:00<00:18, 479k Bytes/s]
# Get sub-02/s .. t_T1w.nii.gz:   4%|▏   | 400k/8.90M [00:00<00:07, 1.18M Bytes/s]
# Get sub-02/s .. t_T1w.nii.gz:   9%|▎   | 766k/8.90M [00:00<00:04, 1.97M Bytes/s]
# Get sub-02/s .. t_T1w.nii.gz:  14%|▍  | 1.22M/8.90M [00:00<00:02, 2.77M Bytes/s]
# Get sub-02/s .. t_T1w.nii.gz:  28%|▊  | 2.46M/8.90M [00:00<00:01, 5.76M Bytes/s]
# Get sub-02/s .. t_T1w.nii.gz:  41%|█▏ | 3.66M/8.90M [00:00<00:00, 7.66M Bytes/s]
# Get sub-02/s .. t_T1w.nii.gz:  53%|█▌ | 4.69M/8.90M [00:00<00:00, 8.46M Bytes/s]
# Get sub-02/s .. t_T1w.nii.gz:  75%|██▎| 6.71M/8.90M [00:00<00:00, 12.0M Bytes/s]
# Get sub-02/s .. t_T1w.nii.gz:  99%|██▉| 8.79M/8.90M [00:01<00:00, 14.6M Bytes/s]
# Total:   0%|                          | 8.90M/2.17G [00:01<07:15, 4.97M Bytes/s]
# Get sub-02/s .. t_dwi.nii.gz:   0%|             | 0.00/101M [00:00<?, ? Bytes/s]
# Get sub-02/s .. t_dwi.nii.gz:   2%|    | 1.75M/101M [00:00<00:05, 16.6M Bytes/s]
# Get sub-02/s .. t_dwi.nii.gz:   5%|▏   | 4.75M/101M [00:00<00:06, 15.3M Bytes/s]
# Get sub-02/s .. t_dwi.nii.gz:   7%|▎   | 6.63M/101M [00:00<00:05, 16.5M Bytes/s]
# Get sub-02/s .. t_dwi.nii.gz:   9%|▎   | 8.79M/101M [00:00<00:05, 18.2M Bytes/s]
# Get sub-02/s .. t_dwi.nii.gz:  12%|▍   | 11.7M/101M [00:00<00:05, 16.5M Bytes/s]
# Get sub-02/s .. t_dwi.nii.gz:  14%|▌   | 14.4M/101M [00:00<00:04, 19.1M Bytes/s]
# Get sub-02/s .. t_dwi.nii.gz:  18%|▋   | 18.6M/101M [00:01<00:04, 19.9M Bytes/s]
# Get sub-02/s .. t_dwi.nii.gz:  20%|▊   | 20.8M/101M [00:01<00:03, 20.2M Bytes/s]
# Get sub-02/s .. t_dwi.nii.gz:  23%|▉   | 22.9M/101M [00:01<00:04, 19.6M Bytes/s]
# Get sub-02/s .. t_dwi.nii.gz:  25%|▉   | 25.0M/101M [00:01<00:03, 20.0M Bytes/s]
# Get sub-02/s .. t_dwi.nii.gz:  27%|█   | 27.2M/101M [00:01<00:03, 20.4M Bytes/s]
# Get sub-02/s .. t_dwi.nii.gz:  29%|█▏  | 29.4M/101M [00:01<00:03, 20.9M Bytes/s]
# Get sub-02/s .. t_dwi.nii.gz:  31%|█▏  | 31.6M/101M [00:01<00:03, 21.2M Bytes/s]
# Get sub-02/s .. t_dwi.nii.gz:  33%|█▎  | 33.8M/101M [00:01<00:03, 21.4M Bytes/s]
# Get sub-02/s .. t_dwi.nii.gz:  38%|█▌  | 38.3M/101M [00:01<00:02, 21.8M Bytes/s]
# Get sub-02/s .. t_dwi.nii.gz:  40%|█▌  | 40.5M/101M [00:02<00:02, 21.9M Bytes/s]
# Get sub-02/s .. t_dwi.nii.gz:  44%|█▊  | 44.7M/101M [00:02<00:02, 21.5M Bytes/s]
# Get sub-02/s .. t_dwi.nii.gz:  47%|█▉  | 48.0M/101M [00:02<00:02, 19.6M Bytes/s]
# Get sub-02/s .. t_dwi.nii.gz:  50%|█▉  | 50.2M/101M [00:02<00:02, 20.2M Bytes/s]
# Get sub-02/s .. t_dwi.nii.gz:  52%|██  | 52.9M/101M [00:02<00:02, 21.7M Bytes/s]
# Get sub-02/s .. t_dwi.nii.gz:  56%|██▎ | 57.2M/101M [00:02<00:02, 21.9M Bytes/s]
# Get sub-02/s .. t_dwi.nii.gz:  59%|██▎ | 59.8M/101M [00:02<00:01, 22.4M Bytes/s]
# Get sub-02/s .. t_dwi.nii.gz:  64%|██▌ | 64.5M/101M [00:03<00:01, 22.8M Bytes/s]
# Get sub-02/s .. t_dwi.nii.gz:  66%|██▋ | 66.9M/101M [00:03<00:01, 23.1M Bytes/s]
# Get sub-02/s .. t_dwi.nii.gz:  71%|██▊ | 71.6M/101M [00:03<00:01, 22.7M Bytes/s]
# Get sub-02/s .. t_dwi.nii.gz:  73%|██▉ | 73.9M/101M [00:03<00:01, 22.8M Bytes/s]
# Get sub-02/s .. t_dwi.nii.gz:  75%|███ | 76.3M/101M [00:03<00:01, 23.0M Bytes/s]
# Get sub-02/s .. t_dwi.nii.gz:  78%|███ | 78.7M/101M [00:03<00:00, 23.2M Bytes/s]
# Get sub-02/s .. t_dwi.nii.gz:  80%|███▏| 81.1M/101M [00:03<00:00, 23.4M Bytes/s]
# Get sub-02/s .. t_dwi.nii.gz:  85%|███▍| 85.9M/101M [00:04<00:00, 23.6M Bytes/s]
# Get sub-02/s .. t_dwi.nii.gz:  87%|███▍| 88.3M/101M [00:04<00:00, 23.7M Bytes/s]
# Get sub-02/s .. t_dwi.nii.gz:  90%|███▌| 90.7M/101M [00:04<00:00, 23.9M Bytes/s]
# Get sub-02/s .. t_dwi.nii.gz:  94%|███▊| 95.4M/101M [00:04<00:00, 23.7M Bytes/s]
# Get sub-02/s .. t_dwi.nii.gz:  97%|███▊| 98.0M/101M [00:04<00:00, 24.2M Bytes/s]
# Get sub-02/s .. t_dwi.nii.gz:  99%|████▉| 100M/101M [00:04<00:00, 24.2M Bytes/s]
#
# Get sub-02/s .. t_dwi.nii.gz:   0%|             | 0.00/101M [00:00<?, ? Bytes/s]
# Total:   5%|█▎                         | 110M/2.17G [00:07<02:17, 15.0M Bytes/s]
# Get sub-02/s .. _bold.nii.gz:   0%|            | 0.00/22.7M [00:00<?, ? Bytes/s]
# Get sub-02/s .. _bold.nii.gz:  22%|▋  | 4.89M/22.7M [00:00<00:00, 24.5M Bytes/s]
# Get sub-02/s .. _bold.nii.gz:  33%|▉  | 7.56M/22.7M [00:00<00:00, 24.3M Bytes/s]
# Get sub-02/s .. _bold.nii.gz:  53%|█▌ | 12.1M/22.7M [00:00<00:00, 24.2M Bytes/s]
# Get sub-02/s .. _bold.nii.gz:  74%|██▏| 16.8M/22.7M [00:00<00:00, 23.8M Bytes/s]
# Get sub-02/s .. _bold.nii.gz:  85%|██▌| 19.4M/22.7M [00:00<00:00, 24.2M Bytes/s]
# Get sub-02/s .. _bold.nii.gz:  96%|██▉| 21.9M/22.7M [00:00<00:00, 24.5M Bytes/s]
#
# Get sub-02/s .. _bold.nii.gz:   0%|            | 0.00/24.4M [00:00<?, ? Bytes/s]
# Get sub-02/s .. _bold.nii.gz:   7%|▏  | 1.71M/24.4M [00:00<00:01, 16.1M Bytes/s]
# Get sub-02/s .. _bold.nii.gz:  17%|▌  | 4.25M/24.4M [00:00<00:01, 13.6M Bytes/s]
# Get sub-02/s .. _bold.nii.gz:  25%|▊  | 6.19M/24.4M [00:00<00:01, 15.3M Bytes/s]
# Get sub-02/s .. _bold.nii.gz:  34%|█  | 8.21M/24.4M [00:00<00:00, 16.8M Bytes/s]
# Get sub-02/s .. _bold.nii.gz:  41%|█▏ | 10.0M/24.4M [00:00<00:00, 17.0M Bytes/s]
# Get sub-02/s .. _bold.nii.gz:  49%|█▍ | 11.9M/24.4M [00:00<00:00, 17.5M Bytes/s]
# Get sub-02/s .. _bold.nii.gz:  64%|█▉ | 15.7M/24.4M [00:00<00:00, 18.2M Bytes/s]
# Get sub-02/s .. _bold.nii.gz:  78%|██▎| 19.1M/24.4M [00:01<00:00, 17.6M Bytes/s]
# Get sub-02/s .. _bold.nii.gz:  87%|██▌| 21.3M/24.4M [00:01<00:00, 18.7M Bytes/s]
#
# Get sub-02/s .. _bold.nii.gz:   0%|            | 0.00/31.2M [00:00<?, ? Bytes/s]
# Get sub-02/s .. _bold.nii.gz:  12%|▎  | 3.79M/31.2M [00:00<00:01, 19.0M Bytes/s]
# Get sub-02/s .. _bold.nii.gz:  25%|▋  | 7.74M/31.2M [00:00<00:01, 19.2M Bytes/s]
# Get sub-02/s .. _bold.nii.gz:  31%|▉  | 9.68M/31.2M [00:00<00:01, 19.2M Bytes/s]
# Get sub-02/s .. _bold.nii.gz:  43%|█▎ | 13.6M/31.2M [00:00<00:00, 19.3M Bytes/s]
# Get sub-02/s .. _bold.nii.gz:  55%|█▋ | 17.1M/31.2M [00:00<00:00, 18.7M Bytes/s]
# Get sub-02/s .. _bold.nii.gz:  62%|█▊ | 19.3M/31.2M [00:01<00:00, 19.2M Bytes/s]
# Get sub-02/s .. _bold.nii.gz:  68%|██ | 21.4M/31.2M [00:01<00:00, 19.7M Bytes/s]
# Get sub-02/s .. _bold.nii.gz:  77%|██▎| 23.9M/31.2M [00:01<00:00, 19.0M Bytes/s]
# Get sub-02/s .. _bold.nii.gz:  87%|██▌| 27.2M/31.2M [00:01<00:00, 19.6M Bytes/s]
# Get sub-02/s .. _bold.nii.gz:  98%|██▉| 30.7M/31.2M [00:01<00:00, 18.7M Bytes/s]
#
# Get sub-02/s .. _bold.nii.gz:   0%|            | 0.00/12.0M [00:00<?, ? Bytes/s]
# Get sub-02/s .. _bold.nii.gz:  30%|▉  | 3.66M/12.0M [00:00<00:00, 18.3M Bytes/s]
# Get sub-02/s .. _bold.nii.gz:  48%|█▍ | 5.73M/12.0M [00:00<00:00, 19.2M Bytes/s]
# Get sub-02/s .. _bold.nii.gz:  77%|██▎| 9.32M/12.0M [00:00<00:00, 18.5M Bytes/s]
#
# Get sub-02/s .. _bold.nii.gz:   0%|            | 0.00/10.4M [00:00<?, ? Bytes/s]
# Get sub-02/s .. _bold.nii.gz:  39%|█▏ | 4.04M/10.4M [00:00<00:00, 20.2M Bytes/s]
# Get sub-02/s .. _bold.nii.gz:  76%|██▎| 7.91M/10.4M [00:00<00:00, 19.7M Bytes/s]
#
# Get sub-02/s .. t_T1w.nii.gz:   0%|            | 0.00/10.0M [00:00<?, ? Bytes/s]
# Get sub-02/s .. t_T1w.nii.gz:  39%|█▏ | 3.88M/10.0M [00:00<00:00, 19.4M Bytes/s]
# Get sub-02/s .. t_T1w.nii.gz:  59%|█▊ | 5.92M/10.0M [00:00<00:00, 19.5M Bytes/s]
# Get sub-02/s .. t_T1w.nii.gz:  80%|██▍| 7.98M/10.0M [00:00<00:00, 19.9M Bytes/s]
# Total:  10%|██▋                        | 221M/2.17G [00:14<02:10, 15.0M Bytes/s]
# Get sub-02/s .. t_dwi.nii.gz:   0%|             | 0.00/104M [00:00<?, ? Bytes/s]
# Get sub-02/s .. t_dwi.nii.gz:   2%|    | 1.94M/104M [00:00<00:05, 18.5M Bytes/s]
# Get sub-02/s .. t_dwi.nii.gz:   4%|▏   | 4.06M/104M [00:00<00:05, 20.0M Bytes/s]
# Get sub-02/s .. t_dwi.nii.gz:   8%|▎   | 7.88M/104M [00:00<00:04, 19.4M Bytes/s]
# Get sub-02/s .. t_dwi.nii.gz:  10%|▍   | 9.92M/104M [00:00<00:04, 19.7M Bytes/s]
# Get sub-02/s .. t_dwi.nii.gz:  12%|▍   | 12.2M/104M [00:00<00:04, 20.7M Bytes/s]
# Get sub-02/s .. t_dwi.nii.gz:  15%|▌   | 15.6M/104M [00:00<00:04, 20.4M Bytes/s]
# Get sub-02/s .. t_dwi.nii.gz:  18%|▋   | 18.3M/104M [00:00<00:04, 20.4M Bytes/s]
# Get sub-02/s .. t_dwi.nii.gz:  20%|▊   | 20.6M/104M [00:01<00:03, 20.9M Bytes/s]
# Get sub-02/s .. t_dwi.nii.gz:  24%|▉   | 24.8M/104M [00:01<00:03, 20.9M Bytes/s]
# Get sub-02/s .. t_dwi.nii.gz:  28%|█   | 28.9M/104M [00:01<00:03, 20.6M Bytes/s]
# Get sub-02/s .. t_dwi.nii.gz:  30%|█▏  | 31.1M/104M [00:01<00:03, 21.0M Bytes/s]
# Get sub-02/s .. t_dwi.nii.gz:  34%|█▎  | 35.2M/104M [00:01<00:03, 20.8M Bytes/s]
# Get sub-02/s .. t_dwi.nii.gz:  38%|█▌  | 39.2M/104M [00:01<00:03, 20.4M Bytes/s]
# Get sub-02/s .. t_dwi.nii.gz:  40%|█▌  | 41.5M/104M [00:02<00:02, 21.0M Bytes/s]
# Get sub-02/s .. t_dwi.nii.gz:  44%|█▊  | 45.6M/104M [00:02<00:02, 20.8M Bytes/s]
# Get sub-02/s .. t_dwi.nii.gz:  48%|█▉  | 49.7M/104M [00:02<00:02, 20.3M Bytes/s]
# Get sub-02/s .. t_dwi.nii.gz:  50%|█▉  | 51.8M/104M [00:02<00:02, 20.5M Bytes/s]
# Get sub-02/s .. t_dwi.nii.gz:  53%|██▏ | 55.7M/104M [00:02<00:02, 20.0M Bytes/s]
# Get sub-02/s .. t_dwi.nii.gz:  56%|██▏ | 58.2M/104M [00:02<00:02, 20.9M Bytes/s]
# Get sub-02/s .. t_dwi.nii.gz:  58%|██▎ | 60.4M/104M [00:02<00:02, 21.2M Bytes/s]
# Get sub-02/s .. t_dwi.nii.gz:  62%|██▍ | 64.4M/104M [00:03<00:01, 20.7M Bytes/s]
# Get sub-02/s .. t_dwi.nii.gz:  65%|██▌ | 67.3M/104M [00:03<00:01, 20.3M Bytes/s]
# Get sub-02/s .. t_dwi.nii.gz:  68%|██▋ | 70.7M/104M [00:03<00:01, 20.6M Bytes/s]
# Get sub-02/s .. t_dwi.nii.gz:  72%|██▊ | 74.8M/104M [00:03<00:01, 20.5M Bytes/s]
# Get sub-02/s .. t_dwi.nii.gz:  74%|██▉ | 77.1M/104M [00:03<00:01, 21.0M Bytes/s]
# Get sub-02/s .. t_dwi.nii.gz:  78%|███ | 81.3M/104M [00:03<00:01, 21.1M Bytes/s]
# Get sub-02/s .. t_dwi.nii.gz:  82%|███▎| 85.6M/104M [00:04<00:00, 21.1M Bytes/s]
# Get sub-02/s .. t_dwi.nii.gz:  85%|███▍| 88.3M/104M [00:04<00:00, 20.7M Bytes/s]
# Get sub-02/s .. t_dwi.nii.gz:  88%|███▌| 91.8M/104M [00:04<00:00, 21.1M Bytes/s]
# Get sub-02/s .. t_dwi.nii.gz:  92%|███▋| 95.8M/104M [00:04<00:00, 20.7M Bytes/s]
# Get sub-02/s .. t_dwi.nii.gz:  95%|███▊| 98.5M/104M [00:04<00:00, 20.3M Bytes/s]
# Get sub-02/s .. t_dwi.nii.gz:  98%|████▉| 102M/104M [00:04<00:00, 20.5M Bytes/s]
#
# Get sub-02/s .. t_dwi.nii.gz:   0%|             | 0.00/104M [00:00<?, ? Bytes/s]
#
# Get sub-02/s .. _bold.nii.gz:   0%|            | 0.00/23.3M [00:00<?, ? Bytes/s]
# Get sub-02/s .. _bold.nii.gz:  17%|▌  | 3.98M/23.3M [00:00<00:00, 19.9M Bytes/s]
# Get sub-02/s .. _bold.nii.gz:  34%|█  | 7.93M/23.3M [00:00<00:00, 19.8M Bytes/s]
# Get sub-02/s .. _bold.nii.gz:  52%|█▌ | 12.1M/23.3M [00:00<00:00, 20.3M Bytes/s]
# Get sub-02/s .. _bold.nii.gz:  69%|██ | 16.1M/23.3M [00:00<00:00, 20.3M Bytes/s]
# Get sub-02/s .. _bold.nii.gz:  78%|██▎| 18.2M/23.3M [00:00<00:00, 20.3M Bytes/s]
# Get sub-02/s .. _bold.nii.gz:  96%|██▉| 22.5M/23.3M [00:01<00:00, 20.6M Bytes/s]
# Total:  16%|████▎                      | 349M/2.17G [00:22<01:55, 15.8M Bytes/s]
# Get sub-02/s .. _bold.nii.gz:   0%|            | 0.00/24.9M [00:00<?, ? Bytes/s]
# Get sub-02/s .. _bold.nii.gz:   7%|▏  | 1.79M/24.9M [00:00<00:01, 17.8M Bytes/s]
# Get sub-02/s .. _bold.nii.gz:  15%|▍  | 3.70M/24.9M [00:00<00:01, 18.6M Bytes/s]
# Get sub-02/s .. _bold.nii.gz:  23%|▋  | 5.78M/24.9M [00:00<00:00, 19.5M Bytes/s]
# Get sub-02/s .. _bold.nii.gz:  31%|▉  | 7.79M/24.9M [00:00<00:00, 19.8M Bytes/s]
# Get sub-02/s .. _bold.nii.gz:  40%|█▏ | 9.94M/24.9M [00:00<00:00, 20.3M Bytes/s]
# Get sub-02/s .. _bold.nii.gz:  48%|█▍ | 12.0M/24.9M [00:00<00:00, 20.1M Bytes/s]
# Get sub-02/s .. _bold.nii.gz:  58%|█▋ | 14.3M/24.9M [00:00<00:00, 21.0M Bytes/s]
# Get sub-02/s .. _bold.nii.gz:  66%|█▉ | 16.4M/24.9M [00:00<00:00, 21.1M Bytes/s]
# Get sub-02/s .. _bold.nii.gz:  75%|██▏| 18.6M/24.9M [00:00<00:00, 21.1M Bytes/s]
# Get sub-02/s .. _bold.nii.gz:  91%|██▋| 22.5M/24.9M [00:01<00:00, 20.5M Bytes/s]
#
# Get sub-02/s .. _bold.nii.gz:   0%|            | 0.00/32.2M [00:00<?, ? Bytes/s]
# Get sub-02/s .. _bold.nii.gz:   6%|▏  | 1.78M/32.2M [00:00<00:01, 17.6M Bytes/s]
# Get sub-02/s .. _bold.nii.gz:  12%|▎  | 3.86M/32.2M [00:00<00:01, 19.4M Bytes/s]
# Get sub-02/s .. _bold.nii.gz:  18%|▌  | 5.88M/32.2M [00:00<00:01, 19.8M Bytes/s]
# Get sub-02/s .. _bold.nii.gz:  31%|▉  | 9.99M/32.2M [00:00<00:01, 20.2M Bytes/s]
# Get sub-02/s .. _bold.nii.gz:  38%|█▏ | 12.1M/32.2M [00:00<00:00, 20.4M Bytes/s]
# Get sub-02/s .. _bold.nii.gz:  48%|█▍ | 15.4M/32.2M [00:00<00:00, 19.9M Bytes/s]
# Get sub-02/s .. _bold.nii.gz:  56%|█▋ | 17.9M/32.2M [00:00<00:00, 19.9M Bytes/s]
# Get sub-02/s .. _bold.nii.gz:  63%|█▉ | 20.4M/32.2M [00:01<00:00, 21.0M Bytes/s]
# Get sub-02/s .. _bold.nii.gz:  76%|██▎| 24.6M/32.2M [00:01<00:00, 20.9M Bytes/s]
# Get sub-02/s .. _bold.nii.gz:  89%|██▋| 28.6M/32.2M [00:01<00:00, 20.5M Bytes/s]
#
# Get sub-02/s .. _bold.nii.gz:   0%|            | 0.00/12.3M [00:00<?, ? Bytes/s]
# Get sub-02/s .. _bold.nii.gz:  17%|▌  | 2.07M/12.3M [00:00<00:00, 20.7M Bytes/s]
# Get sub-02/s .. _bold.nii.gz:  45%|█▎ | 5.58M/12.3M [00:00<00:00, 19.2M Bytes/s]
# Get sub-02/s .. _bold.nii.gz:  62%|█▊ | 7.61M/12.3M [00:00<00:00, 18.5M Bytes/s]
# Get sub-02/s .. _bold.nii.gz:  87%|██▌| 10.8M/12.3M [00:00<00:00, 17.2M Bytes/s]
#
# Get sub-02/s .. _bold.nii.gz:   0%|            | 0.00/10.5M [00:00<?, ? Bytes/s]
# Get sub-02/s .. _bold.nii.gz:  31%|▉  | 3.28M/10.5M [00:00<00:00, 16.4M Bytes/s]
# Get sub-02/s .. _bold.nii.gz:  47%|█▍ | 4.96M/10.5M [00:00<00:00, 16.6M Bytes/s]
# Get sub-02/s .. _bold.nii.gz:  80%|██▍| 8.37M/10.5M [00:00<00:00, 16.7M Bytes/s]
#
# Get sub-01/s .. t_T1w.nii.gz:   0%|            | 0.00/8.50M [00:00<?, ? Bytes/s]
# Get sub-01/s .. t_T1w.nii.gz:  39%|█▏ | 3.31M/8.50M [00:00<00:00, 16.4M Bytes/s]
# Get sub-01/s .. t_T1w.nii.gz:  61%|█▊ | 5.21M/8.50M [00:00<00:00, 17.4M Bytes/s]
#
# Get sub-01/s .. t_dwi.nii.gz:   0%|            | 0.00/99.9M [00:00<?, ? Bytes/s]
# Get sub-01/s .. t_dwi.nii.gz:   4%|   | 3.59M/99.9M [00:00<00:05, 17.9M Bytes/s]
# Get sub-01/s .. t_dwi.nii.gz:   5%|▏  | 5.38M/99.9M [00:00<00:05, 17.9M Bytes/s]
# Get sub-01/s .. t_dwi.nii.gz:   7%|▏  | 7.28M/99.9M [00:00<00:05, 18.3M Bytes/s]
# Get sub-01/s .. t_dwi.nii.gz:  11%|▎  | 10.8M/99.9M [00:00<00:04, 17.9M Bytes/s]
# Get sub-01/s .. t_dwi.nii.gz:  13%|▍  | 12.7M/99.9M [00:00<00:04, 18.1M Bytes/s]
# Get sub-01/s .. t_dwi.nii.gz:  15%|▍  | 14.8M/99.9M [00:00<00:04, 18.8M Bytes/s]
# Get sub-01/s .. t_dwi.nii.gz:  19%|▌  | 18.5M/99.9M [00:01<00:04, 18.8M Bytes/s]
# Get sub-01/s .. t_dwi.nii.gz:  22%|▋  | 22.2M/99.9M [00:01<00:04, 18.5M Bytes/s]
# Get sub-01/s .. t_dwi.nii.gz:  24%|▋  | 24.1M/99.9M [00:01<00:04, 18.7M Bytes/s]
# Get sub-01/s .. t_dwi.nii.gz:  26%|▊  | 26.0M/99.9M [00:01<00:03, 18.9M Bytes/s]
# Get sub-01/s .. t_dwi.nii.gz:  30%|▉  | 30.0M/99.9M [00:01<00:03, 19.3M Bytes/s]
# Get sub-01/s .. t_dwi.nii.gz:  32%|▉  | 32.1M/99.9M [00:01<00:03, 19.5M Bytes/s]
# Get sub-01/s .. t_dwi.nii.gz:  36%|█  | 35.9M/99.9M [00:01<00:03, 19.3M Bytes/s]
# Get sub-01/s .. t_dwi.nii.gz:  40%|█▏ | 39.7M/99.9M [00:02<00:03, 19.0M Bytes/s]
# Get sub-01/s .. t_dwi.nii.gz:  42%|█▏ | 41.6M/99.9M [00:02<00:03, 19.0M Bytes/s]
# Get sub-01/s .. t_dwi.nii.gz:  46%|█▎ | 45.6M/99.9M [00:02<00:02, 19.4M Bytes/s]
# Get sub-01/s .. t_dwi.nii.gz:  48%|█▍ | 47.7M/99.9M [00:02<00:02, 19.5M Bytes/s]
# Get sub-01/s .. t_dwi.nii.gz:  50%|█▍ | 49.7M/99.9M [00:02<00:02, 19.7M Bytes/s]
# Get sub-01/s .. t_dwi.nii.gz:  52%|█▌ | 51.8M/99.9M [00:02<00:02, 19.9M Bytes/s]
# Get sub-01/s .. t_dwi.nii.gz:  56%|█▋ | 55.9M/99.9M [00:02<00:02, 20.1M Bytes/s]
# Get sub-01/s .. t_dwi.nii.gz:  60%|█▊ | 59.8M/99.9M [00:03<00:02, 19.9M Bytes/s]
# Get sub-01/s .. t_dwi.nii.gz:  62%|█▊ | 61.9M/99.9M [00:03<00:01, 19.9M Bytes/s]
# Get sub-01/s .. t_dwi.nii.gz:  64%|█▉ | 64.1M/99.9M [00:03<00:01, 20.4M Bytes/s]
# Get sub-01/s .. t_dwi.nii.gz:  66%|█▉ | 66.2M/99.9M [00:03<00:01, 20.5M Bytes/s]
# Get sub-01/s .. t_dwi.nii.gz:  71%|██ | 70.5M/99.9M [00:03<00:01, 20.8M Bytes/s]
# Get sub-01/s .. t_dwi.nii.gz:  73%|██▏| 73.0M/99.9M [00:03<00:01, 19.8M Bytes/s]
# Get sub-01/s .. t_dwi.nii.gz:  77%|██▎| 76.5M/99.9M [00:03<00:01, 20.5M Bytes/s]
# Get sub-01/s .. t_dwi.nii.gz:  79%|██▎| 78.8M/99.9M [00:04<00:01, 21.1M Bytes/s]
# Get sub-01/s .. t_dwi.nii.gz:  83%|██▍| 82.7M/99.9M [00:04<00:00, 20.4M Bytes/s]
# Get sub-01/s .. t_dwi.nii.gz:  85%|██▌| 84.8M/99.9M [00:04<00:00, 20.6M Bytes/s]
# Get sub-01/s .. t_dwi.nii.gz:  89%|██▋| 88.9M/99.9M [00:04<00:00, 19.9M Bytes/s]
# Get sub-01/s .. t_dwi.nii.gz:  93%|██▊| 93.2M/99.9M [00:04<00:00, 20.2M Bytes/s]
# Get sub-01/s .. t_dwi.nii.gz:  97%|██▉| 97.2M/99.9M [00:04<00:00, 20.2M Bytes/s]
# Get sub-01/s .. t_dwi.nii.gz:  99%|██▉| 99.4M/99.9M [00:05<00:00, 20.4M Bytes/s]
#
# Get sub-01/s .. t_dwi.nii.gz:   0%|            | 0.00/99.9M [00:00<?, ? Bytes/s]
# Total:  25%|██████▋                    | 537M/2.17G [00:34<01:43, 15.7M Bytes/s]
# Get sub-01/s .. _bold.nii.gz:   0%|            | 0.00/22.3M [00:00<?, ? Bytes/s]
# Get sub-01/s .. _bold.nii.gz:   7%|▏  | 1.66M/22.3M [00:00<00:01, 15.6M Bytes/s]
# Get sub-01/s .. _bold.nii.gz:  16%|▍  | 3.63M/22.3M [00:00<00:01, 11.4M Bytes/s]
# Get sub-01/s .. _bold.nii.gz:  23%|▋  | 5.19M/22.3M [00:00<00:01, 12.5M Bytes/s]
# Get sub-01/s .. _bold.nii.gz:  31%|▉  | 6.96M/22.3M [00:00<00:01, 14.1M Bytes/s]
# Get sub-01/s .. _bold.nii.gz:  44%|█▎ | 9.73M/22.3M [00:00<00:00, 14.0M Bytes/s]
# Get sub-01/s .. _bold.nii.gz:  52%|█▌ | 11.7M/22.3M [00:00<00:00, 15.4M Bytes/s]
# Get sub-01/s .. _bold.nii.gz:  67%|██ | 14.9M/22.3M [00:01<00:00, 15.7M Bytes/s]
# Get sub-01/s .. _bold.nii.gz:  80%|██▍| 17.8M/22.3M [00:01<00:00, 15.2M Bytes/s]
# Get sub-01/s .. _bold.nii.gz:  87%|██▌| 19.4M/22.3M [00:01<00:00, 15.4M Bytes/s]
# Get sub-01/s .. _bold.nii.gz:  95%|██▊| 21.2M/22.3M [00:01<00:00, 15.9M Bytes/s]
# Total:  26%|██████▉                    | 559M/2.17G [00:35<01:43, 15.6M Bytes/s]
# Get sub-01/s .. _bold.nii.gz:   0%|            | 0.00/23.8M [00:00<?, ? Bytes/s]
# Get sub-01/s .. _bold.nii.gz:   7%|▏  | 1.58M/23.8M [00:00<00:01, 15.1M Bytes/s]
# Get sub-01/s .. _bold.nii.gz:  14%|▍  | 3.41M/23.8M [00:00<00:01, 17.0M Bytes/s]
# Get sub-01/s .. _bold.nii.gz:  28%|▊  | 6.77M/23.8M [00:00<00:01, 16.8M Bytes/s]
# Get sub-01/s .. _bold.nii.gz:  36%|█  | 8.48M/23.8M [00:00<00:00, 16.9M Bytes/s]
# Get sub-01/s .. _bold.nii.gz:  49%|█▍ | 11.7M/23.8M [00:00<00:00, 16.6M Bytes/s]
# Get sub-01/s .. _bold.nii.gz:  64%|█▉ | 15.2M/23.8M [00:00<00:00, 16.7M Bytes/s]
# Get sub-01/s .. _bold.nii.gz:  78%|██▎| 18.6M/23.8M [00:01<00:00, 16.9M Bytes/s]
# Get sub-01/s .. _bold.nii.gz:  87%|██▌| 20.7M/23.8M [00:01<00:00, 16.3M Bytes/s]
# Get sub-01/s .. _bold.nii.gz: 100%|██▉| 23.7M/23.8M [00:01<00:00, 17.0M Bytes/s]
# Total:  27%|███████▏                   | 583M/2.17G [00:37<01:42, 15.5M Bytes/s]
# Get sub-01/s .. _bold.nii.gz:   0%|            | 0.00/30.7M [00:00<?, ? Bytes/s]
# Get sub-01/s .. _bold.nii.gz:   5%|▏  | 1.65M/30.7M [00:00<00:01, 16.1M Bytes/s]
# Get sub-01/s .. _bold.nii.gz:  11%|▎  | 3.42M/30.7M [00:00<00:01, 17.0M Bytes/s]
# Get sub-01/s .. _bold.nii.gz:  23%|▋  | 7.00M/30.7M [00:00<00:01, 17.4M Bytes/s]
# Get sub-01/s .. _bold.nii.gz:  34%|█  | 10.5M/30.7M [00:00<00:01, 17.5M Bytes/s]
# Get sub-01/s .. _bold.nii.gz:  40%|█▏ | 12.3M/30.7M [00:00<00:01, 17.5M Bytes/s]
# Get sub-01/s .. _bold.nii.gz:  46%|█▍ | 14.1M/30.7M [00:00<00:00, 17.6M Bytes/s]
# Get sub-01/s .. _bold.nii.gz:  52%|█▌ | 15.9M/30.7M [00:00<00:00, 17.7M Bytes/s]
# Get sub-01/s .. _bold.nii.gz:  58%|█▋ | 17.7M/30.7M [00:01<00:00, 17.7M Bytes/s]
# Get sub-01/s .. _bold.nii.gz:  63%|█▉ | 19.5M/30.7M [00:01<00:00, 17.8M Bytes/s]
# Get sub-01/s .. _bold.nii.gz:  73%|██▏| 22.6M/30.7M [00:01<00:00, 17.4M Bytes/s]
# Get sub-01/s .. _bold.nii.gz:  81%|██▍| 24.8M/30.7M [00:01<00:00, 17.8M Bytes/s]
# Get sub-01/s .. _bold.nii.gz:  91%|██▋| 28.0M/30.7M [00:01<00:00, 17.1M Bytes/s]
# Get sub-01/s .. _bold.nii.gz:  98%|██▉| 30.1M/30.7M [00:01<00:00, 18.0M Bytes/s]
# Total:  28%|███████▋                   | 614M/2.17G [00:39<01:40, 15.5M Bytes/s]
# Get sub-01/s .. _bold.nii.gz:   0%|            | 0.00/11.8M [00:00<?, ? Bytes/s]
# Get sub-01/s .. _bold.nii.gz:  30%|▉  | 3.52M/11.8M [00:00<00:00, 17.3M Bytes/s]
# Get sub-01/s .. _bold.nii.gz:  47%|█▍ | 5.53M/11.8M [00:00<00:00, 18.4M Bytes/s]
# Get sub-01/s .. _bold.nii.gz:  76%|██▎| 9.02M/11.8M [00:00<00:00, 17.9M Bytes/s]
#
# Get sub-01/s .. _bold.nii.gz:   0%|            | 0.00/10.2M [00:00<?, ? Bytes/s]
# Get sub-01/s .. _bold.nii.gz:  17%|▌  | 1.74M/10.2M [00:00<00:00, 16.6M Bytes/s]
# Get sub-01/s .. _bold.nii.gz:  37%|█  | 3.74M/10.2M [00:00<00:00, 18.5M Bytes/s]
# Get sub-01/s .. _bold.nii.gz:  72%|██▏| 7.29M/10.2M [00:00<00:00, 17.9M Bytes/s]
#
# Get sub-01/s .. t_T1w.nii.gz:   0%|            | 0.00/8.68M [00:00<?, ? Bytes/s]
# Get sub-01/s .. t_T1w.nii.gz:  21%|▋  | 1.85M/8.68M [00:00<00:00, 18.5M Bytes/s]
# Get sub-01/s .. t_T1w.nii.gz:  60%|█▊ | 5.18M/8.68M [00:00<00:00, 18.1M Bytes/s]
# Get sub-01/s .. t_T1w.nii.gz:  83%|██▌| 7.24M/8.68M [00:00<00:00, 18.0M Bytes/s]
#
# Get sub-01/s .. t_dwi.nii.gz:   0%|             | 0.00/104M [00:00<?, ? Bytes/s]
# Get sub-01/s .. t_dwi.nii.gz:   2%|    | 1.82M/104M [00:00<00:05, 18.2M Bytes/s]
# Get sub-01/s .. t_dwi.nii.gz:   4%|▏   | 3.67M/104M [00:00<00:05, 18.4M Bytes/s]
# Get sub-01/s .. t_dwi.nii.gz:   5%|▏   | 5.53M/104M [00:00<00:05, 18.4M Bytes/s]
# Get sub-01/s .. t_dwi.nii.gz:   9%|▎   | 9.01M/104M [00:00<00:05, 17.8M Bytes/s]
# Get sub-01/s .. t_dwi.nii.gz:  11%|▍   | 11.0M/104M [00:00<00:05, 18.5M Bytes/s]
# Get sub-01/s .. t_dwi.nii.gz:  13%|▌   | 13.3M/104M [00:00<00:04, 18.7M Bytes/s]
# Get sub-01/s .. t_dwi.nii.gz:  16%|▋   | 16.3M/104M [00:00<00:04, 17.8M Bytes/s]
# Get sub-01/s .. t_dwi.nii.gz:  17%|▋   | 18.2M/104M [00:01<00:04, 17.9M Bytes/s]
# Get sub-01/s .. t_dwi.nii.gz:  19%|▊   | 20.2M/104M [00:01<00:04, 18.5M Bytes/s]
# Get sub-01/s .. t_dwi.nii.gz:  21%|▊   | 22.2M/104M [00:01<00:04, 18.3M Bytes/s]
# Get sub-01/s .. t_dwi.nii.gz:  24%|▉   | 25.2M/104M [00:01<00:04, 17.3M Bytes/s]
# Get sub-01/s .. t_dwi.nii.gz:  27%|█   | 28.4M/104M [00:01<00:04, 16.7M Bytes/s]
# Get sub-01/s .. t_dwi.nii.gz:  29%|█▏  | 30.7M/104M [00:01<00:04, 18.1M Bytes/s]
# Get sub-01/s .. t_dwi.nii.gz:  33%|█▎  | 34.8M/104M [00:01<00:03, 18.4M Bytes/s]
# Get sub-01/s .. t_dwi.nii.gz:  37%|█▍  | 38.0M/104M [00:02<00:03, 17.6M Bytes/s]
# Get sub-01/s .. t_dwi.nii.gz:  38%|█▌  | 40.0M/104M [00:02<00:03, 18.0M Bytes/s]
# Get sub-01/s .. t_dwi.nii.gz:  42%|█▋  | 43.6M/104M [00:02<00:03, 17.9M Bytes/s]
# Get sub-01/s .. t_dwi.nii.gz:  44%|█▋  | 45.5M/104M [00:02<00:03, 18.0M Bytes/s]
# Get sub-01/s .. t_dwi.nii.gz:  45%|█▊  | 47.3M/104M [00:02<00:03, 18.1M Bytes/s]
# Get sub-01/s .. t_dwi.nii.gz:  49%|█▉  | 51.0M/104M [00:02<00:02, 18.2M Bytes/s]
# Get sub-01/s .. t_dwi.nii.gz:  52%|██  | 54.7M/104M [00:03<00:02, 18.2M Bytes/s]
# Get sub-01/s .. t_dwi.nii.gz:  54%|██▏ | 56.5M/104M [00:03<00:02, 18.3M Bytes/s]
# Get sub-01/s .. t_dwi.nii.gz:  58%|██▎ | 60.2M/104M [00:03<00:02, 18.3M Bytes/s]
# Get sub-01/s .. t_dwi.nii.gz:  61%|██▍ | 63.7M/104M [00:03<00:02, 18.0M Bytes/s]
# Get sub-01/s .. t_dwi.nii.gz:  63%|██▌ | 65.8M/104M [00:03<00:02, 18.5M Bytes/s]
# Get sub-01/s .. t_dwi.nii.gz:  67%|██▋ | 69.5M/104M [00:03<00:01, 18.5M Bytes/s]
# Get sub-01/s .. t_dwi.nii.gz:  70%|██▊ | 73.1M/104M [00:04<00:01, 17.9M Bytes/s]
# Get sub-01/s .. t_dwi.nii.gz:  73%|██▉ | 76.5M/104M [00:04<00:01, 18.4M Bytes/s]
# Get sub-01/s .. t_dwi.nii.gz:  75%|███ | 78.4M/104M [00:04<00:01, 17.6M Bytes/s]
# Get sub-01/s .. t_dwi.nii.gz:  77%|███ | 80.1M/104M [00:04<00:01, 17.6M Bytes/s]
# Get sub-01/s .. t_dwi.nii.gz:  79%|███▏| 82.0M/104M [00:04<00:01, 17.7M Bytes/s]
# Get sub-01/s .. t_dwi.nii.gz:  80%|███▏| 83.8M/104M [00:04<00:01, 17.9M Bytes/s]
# Get sub-01/s .. t_dwi.nii.gz:  82%|███▎| 85.7M/104M [00:04<00:01, 18.1M Bytes/s]
# Get sub-01/s .. t_dwi.nii.gz:  84%|███▎| 87.5M/104M [00:04<00:00, 18.2M Bytes/s]
# Get sub-01/s .. t_dwi.nii.gz:  86%|███▍| 89.4M/104M [00:04<00:00, 18.3M Bytes/s]
# Get sub-01/s .. t_dwi.nii.gz:  88%|███▌| 91.3M/104M [00:05<00:00, 18.4M Bytes/s]
# Get sub-01/s .. t_dwi.nii.gz:  90%|███▌| 94.3M/104M [00:05<00:00, 17.9M Bytes/s]
# Get sub-01/s .. t_dwi.nii.gz:  93%|███▋| 96.8M/104M [00:05<00:00, 18.6M Bytes/s]
# Get sub-01/s .. t_dwi.nii.gz:  96%|████▊| 101M/104M [00:05<00:00, 18.6M Bytes/s]
# Get sub-01/s .. t_dwi.nii.gz:  99%|████▉| 103M/104M [00:05<00:00, 17.9M Bytes/s]
# Total:  34%|█████████▎                 | 749M/2.17G [00:48<01:32, 15.3M Bytes/s]
# Get sub-01/s .. _bold.nii.gz:   0%|            | 0.00/22.9M [00:00<?, ? Bytes/s]
# Get sub-01/s .. _bold.nii.gz:   8%|▏  | 1.88M/22.9M [00:00<00:01, 18.7M Bytes/s]
# Get sub-01/s .. _bold.nii.gz:  24%|▋  | 5.61M/22.9M [00:00<00:00, 18.7M Bytes/s]
# Get sub-01/s .. _bold.nii.gz:  33%|▉  | 7.48M/22.9M [00:00<00:00, 18.7M Bytes/s]
# Get sub-01/s .. _bold.nii.gz:  41%|█▏ | 9.37M/22.9M [00:00<00:00, 18.7M Bytes/s]
# Get sub-01/s .. _bold.nii.gz:  55%|█▋ | 12.6M/22.9M [00:00<00:00, 18.1M Bytes/s]
# Get sub-01/s .. _bold.nii.gz:  65%|█▉ | 14.9M/22.9M [00:00<00:00, 18.5M Bytes/s]
# Get sub-01/s .. _bold.nii.gz:  73%|██▏| 16.8M/22.9M [00:00<00:00, 18.8M Bytes/s]
# Get sub-01/s .. _bold.nii.gz:  82%|██▍| 18.8M/22.9M [00:01<00:00, 19.1M Bytes/s]
# Get sub-01/s .. _bold.nii.gz:  96%|██▊| 21.9M/22.9M [00:01<00:00, 18.3M Bytes/s]
#
# Get sub-01/s .. _bold.nii.gz:   0%|            | 0.00/24.5M [00:00<?, ? Bytes/s]
# Get sub-01/s .. _bold.nii.gz:   8%|▏  | 1.90M/24.5M [00:00<00:01, 18.9M Bytes/s]
# Get sub-01/s .. _bold.nii.gz:  18%|▌  | 4.49M/24.5M [00:00<00:01, 19.7M Bytes/s]
# Get sub-01/s .. _bold.nii.gz:  30%|▉  | 7.43M/24.5M [00:00<00:00, 18.2M Bytes/s]
# Get sub-01/s .. _bold.nii.gz:  47%|█▍ | 11.5M/24.5M [00:00<00:00, 19.1M Bytes/s]
# Get sub-01/s .. _bold.nii.gz:  55%|█▋ | 13.4M/24.5M [00:00<00:00, 19.1M Bytes/s]
# Get sub-01/s .. _bold.nii.gz:  63%|█▉ | 15.3M/24.5M [00:00<00:00, 19.2M Bytes/s]
# Get sub-01/s .. _bold.nii.gz:  78%|██▎| 19.2M/24.5M [00:01<00:00, 19.2M Bytes/s]
# Get sub-01/s .. _bold.nii.gz:  86%|██▌| 21.1M/24.5M [00:01<00:00, 19.2M Bytes/s]
# Get sub-01/s .. _bold.nii.gz:  96%|██▊| 23.4M/24.5M [00:01<00:00, 18.9M Bytes/s]
#
# Get sub-01/s .. _bold.nii.gz:   0%|            | 0.00/31.6M [00:00<?, ? Bytes/s]
# Get sub-01/s .. _bold.nii.gz:   6%|▏  | 1.89M/31.6M [00:00<00:01, 18.0M Bytes/s]
# Get sub-01/s .. _bold.nii.gz:  12%|▎  | 3.88M/31.6M [00:00<00:01, 19.1M Bytes/s]
# Get sub-01/s .. _bold.nii.gz:  19%|▌  | 5.99M/31.6M [00:00<00:01, 19.9M Bytes/s]
# Get sub-01/s .. _bold.nii.gz:  31%|▉  | 9.77M/31.6M [00:00<00:01, 19.3M Bytes/s]
# Get sub-01/s .. _bold.nii.gz:  44%|█▎ | 13.8M/31.6M [00:00<00:00, 19.6M Bytes/s]
# Get sub-01/s .. _bold.nii.gz:  56%|█▋ | 17.8M/31.6M [00:00<00:00, 19.8M Bytes/s]
# Get sub-01/s .. _bold.nii.gz:  69%|██ | 21.7M/31.6M [00:01<00:00, 19.7M Bytes/s]
# Get sub-01/s .. _bold.nii.gz:  80%|██▍| 25.3M/31.6M [00:01<00:00, 19.7M Bytes/s]
# Get sub-01/s .. _bold.nii.gz:  87%|██▌| 27.6M/31.6M [00:01<00:00, 14.8M Bytes/s]
# Get sub-01/s .. _bold.nii.gz:  93%|██▊| 29.5M/31.6M [00:01<00:00, 15.6M Bytes/s]
# Get sub-01/s .. _bold.nii.gz:  99%|██▉| 31.4M/31.6M [00:01<00:00, 16.2M Bytes/s]
#
# Get sub-01/s .. _bold.nii.gz:   0%|            | 0.00/12.0M [00:00<?, ? Bytes/s]
# Get sub-01/s .. _bold.nii.gz:  12%|▎  | 1.50M/12.0M [00:00<00:00, 15.0M Bytes/s]
# Get sub-01/s .. _bold.nii.gz:  25%|▊  | 3.04M/12.0M [00:00<00:00, 15.2M Bytes/s]
# Get sub-01/s .. _bold.nii.gz:  49%|█▍ | 5.90M/12.0M [00:00<00:00, 14.6M Bytes/s]
# Get sub-01/s .. _bold.nii.gz:  62%|█▊ | 7.49M/12.0M [00:00<00:00, 15.0M Bytes/s]
# Get sub-01/s .. _bold.nii.gz:  87%|██▌| 10.5M/12.0M [00:00<00:00, 15.0M Bytes/s]
#
# Get sub-01/s .. _bold.nii.gz:   0%|            | 0.00/10.4M [00:00<?, ? Bytes/s]
# Get sub-01/s .. _bold.nii.gz:  31%|▉  | 3.24M/10.4M [00:00<00:00, 16.3M Bytes/s]
# Get sub-01/s .. _bold.nii.gz:  63%|█▉ | 6.48M/10.4M [00:00<00:00, 15.9M Bytes/s]
# Get sub-01/s .. _bold.nii.gz:  97%|██▉| 10.0M/10.4M [00:00<00:00, 16.7M Bytes/s]
#
# Get sub-05/s .. t_T1w.nii.gz:   0%|            | 0.00/9.51M [00:00<?, ? Bytes/s]
# Get sub-05/s .. t_T1w.nii.gz:  36%|█  | 3.42M/9.51M [00:00<00:00, 17.1M Bytes/s]
# Get sub-05/s .. t_T1w.nii.gz:  70%|██ | 6.70M/9.51M [00:00<00:00, 16.6M Bytes/s]
# Get sub-05/s .. t_T1w.nii.gz:  88%|██▋| 8.41M/9.51M [00:00<00:00, 16.7M Bytes/s]
#
# Get sub-05/s .. t_dwi.nii.gz:   0%|             | 0.00/104M [00:00<?, ? Bytes/s]
# Get sub-05/s .. t_dwi.nii.gz:   2%|    | 1.77M/104M [00:00<00:06, 16.8M Bytes/s]
# Get sub-05/s .. t_dwi.nii.gz:   4%|▏   | 3.71M/104M [00:00<00:05, 18.2M Bytes/s]
# Get sub-05/s .. t_dwi.nii.gz:   7%|▎   | 7.29M/104M [00:00<00:05, 18.0M Bytes/s]
# Get sub-05/s .. t_dwi.nii.gz:  10%|▍   | 10.6M/104M [00:00<00:05, 17.3M Bytes/s]
# Get sub-05/s .. t_dwi.nii.gz:  12%|▍   | 12.5M/104M [00:00<00:05, 17.7M Bytes/s]
# Get sub-05/s .. t_dwi.nii.gz:  14%|▌   | 14.3M/104M [00:00<00:05, 17.8M Bytes/s]
# Get sub-05/s .. t_dwi.nii.gz:  15%|▌   | 16.1M/104M [00:00<00:04, 17.8M Bytes/s]
# Get sub-05/s .. t_dwi.nii.gz:  19%|▊   | 19.7M/104M [00:01<00:04, 17.9M Bytes/s]
# Get sub-05/s .. t_dwi.nii.gz:  21%|▊   | 21.6M/104M [00:01<00:04, 18.0M Bytes/s]
# Get sub-05/s .. t_dwi.nii.gz:  23%|▉   | 23.6M/104M [00:01<00:04, 18.7M Bytes/s]
# Get sub-05/s .. t_dwi.nii.gz:  26%|█   | 27.3M/104M [00:01<00:04, 18.5M Bytes/s]
# Get sub-05/s .. t_dwi.nii.gz:  28%|█   | 29.2M/104M [00:01<00:04, 18.4M Bytes/s]
# Get sub-05/s .. t_dwi.nii.gz:  32%|█▎  | 32.9M/104M [00:01<00:03, 18.3M Bytes/s]
# Get sub-05/s .. t_dwi.nii.gz:  33%|█▎  | 34.7M/104M [00:01<00:03, 18.1M Bytes/s]
# Get sub-05/s .. t_dwi.nii.gz:  35%|█▍  | 36.6M/104M [00:02<00:03, 18.0M Bytes/s]
# Get sub-05/s .. t_dwi.nii.gz:  37%|█▍  | 38.5M/104M [00:02<00:03, 18.3M Bytes/s]
# Get sub-05/s .. t_dwi.nii.gz:  41%|█▋  | 42.3M/104M [00:02<00:03, 18.5M Bytes/s]
# Get sub-05/s .. t_dwi.nii.gz:  43%|█▋  | 44.3M/104M [00:02<00:03, 18.7M Bytes/s]
# Total:  40%|██████████▋                | 860M/2.17G [01:00<01:31, 14.3M Bytes/s]
# Get sub-05/s .. t_dwi.nii.gz:  50%|██  | 52.1M/104M [00:02<00:02, 19.0M Bytes/s]
# Get sub-05/s .. t_dwi.nii.gz:  52%|██  | 54.0M/104M [00:02<00:02, 19.2M Bytes/s]
# Get sub-05/s .. t_dwi.nii.gz:  55%|██▏ | 57.7M/104M [00:03<00:02, 18.8M Bytes/s]
# Get sub-05/s .. t_dwi.nii.gz:  58%|██▎ | 60.0M/104M [00:03<00:02, 19.7M Bytes/s]
# Get sub-05/s .. t_dwi.nii.gz:  62%|██▍ | 64.0M/104M [00:03<00:02, 19.5M Bytes/s]
# Get sub-05/s .. t_dwi.nii.gz:  65%|██▌ | 68.0M/104M [00:03<00:01, 19.6M Bytes/s]
# Get sub-05/s .. t_dwi.nii.gz:  69%|██▊ | 71.9M/104M [00:03<00:01, 19.5M Bytes/s]
# Get sub-05/s .. t_dwi.nii.gz:  73%|██▉ | 75.7M/104M [00:04<00:01, 19.3M Bytes/s]
# Get sub-05/s .. t_dwi.nii.gz:  75%|██▉ | 77.6M/104M [00:04<00:01, 19.0M Bytes/s]
# Get sub-05/s .. t_dwi.nii.gz:  77%|███ | 79.7M/104M [00:04<00:01, 19.3M Bytes/s]
# Get sub-05/s .. t_dwi.nii.gz:  79%|███▏| 81.7M/104M [00:04<00:01, 19.5M Bytes/s]
# Get sub-05/s .. t_dwi.nii.gz:  80%|███▏| 83.7M/104M [00:04<00:01, 19.5M Bytes/s]
# Get sub-05/s .. t_dwi.nii.gz:  82%|███▎| 85.8M/104M [00:04<00:00, 19.8M Bytes/s]
# Get sub-05/s .. t_dwi.nii.gz:  84%|███▍| 87.8M/104M [00:04<00:00, 19.9M Bytes/s]
# Get sub-05/s .. t_dwi.nii.gz:  86%|███▍| 89.8M/104M [00:04<00:00, 20.0M Bytes/s]
# Get sub-05/s .. t_dwi.nii.gz:  88%|███▌| 91.9M/104M [00:04<00:00, 20.1M Bytes/s]
# Get sub-05/s .. t_dwi.nii.gz:  92%|███▋| 95.8M/104M [00:05<00:00, 19.8M Bytes/s]
# Get sub-05/s .. t_dwi.nii.gz:  94%|███▊| 97.8M/104M [00:05<00:00, 19.9M Bytes/s]
# Get sub-05/s .. t_dwi.nii.gz:  97%|████▊| 101M/104M [00:05<00:00, 17.8M Bytes/s]
# Get sub-05/s .. t_dwi.nii.gz:  99%|████▉| 103M/104M [00:05<00:00, 18.2M Bytes/s]
#
# Get sub-05/s .. t_dwi.nii.gz:   0%|             | 0.00/104M [00:00<?, ? Bytes/s]
# Total:  44%|███████████▉               | 964M/2.17G [01:03<01:19, 15.2M Bytes/s]
# Get sub-05/s .. _bold.nii.gz:   0%|            | 0.00/24.2M [00:00<?, ? Bytes/s]
# Get sub-05/s .. _bold.nii.gz:  17%|▍  | 4.02M/24.2M [00:00<00:01, 20.1M Bytes/s]
# Get sub-05/s .. _bold.nii.gz:  25%|▊  | 6.07M/24.2M [00:00<00:00, 20.2M Bytes/s]
# Get sub-05/s .. _bold.nii.gz:  33%|█  | 8.12M/24.2M [00:00<00:00, 20.3M Bytes/s]
# Get sub-05/s .. _bold.nii.gz:  42%|█▎ | 10.2M/24.2M [00:00<00:00, 20.4M Bytes/s]
# Get sub-05/s .. _bold.nii.gz:  50%|█▌ | 12.2M/24.2M [00:00<00:00, 20.4M Bytes/s]
# Get sub-05/s .. _bold.nii.gz:  64%|█▉ | 15.5M/24.2M [00:00<00:00, 20.6M Bytes/s]
# Get sub-05/s .. _bold.nii.gz:  75%|██▏| 18.1M/24.2M [00:00<00:00, 19.6M Bytes/s]
# Get sub-05/s .. _bold.nii.gz:  83%|██▍| 20.1M/24.2M [00:01<00:00, 19.5M Bytes/s]
# Get sub-05/s .. _bold.nii.gz:  91%|██▋| 22.1M/24.2M [00:01<00:00, 19.8M Bytes/s]
# Get sub-05/s .. _bold.nii.gz: 100%|██▉| 24.2M/24.2M [00:01<00:00, 19.9M Bytes/s]
# Total:  45%|████████████▎              | 988M/2.17G [01:04<01:17, 15.2M Bytes/s]
# Get sub-05/s .. _bold.nii.gz:   0%|            | 0.00/26.0M [00:00<?, ? Bytes/s]
# Get sub-05/s .. _bold.nii.gz:  14%|▍  | 3.60M/26.0M [00:00<00:01, 17.8M Bytes/s]
# Get sub-05/s .. _bold.nii.gz:  26%|▊  | 6.69M/26.0M [00:00<00:01, 16.4M Bytes/s]
# Get sub-05/s .. _bold.nii.gz:  32%|▉  | 8.37M/26.0M [00:00<00:01, 16.5M Bytes/s]
# Get sub-05/s .. _bold.nii.gz:  43%|█▎ | 11.1M/26.0M [00:00<00:00, 15.2M Bytes/s]
# Get sub-05/s .. _bold.nii.gz:  49%|█▍ | 12.7M/26.0M [00:00<00:00, 15.4M Bytes/s]
# Get sub-05/s .. _bold.nii.gz:  61%|█▊ | 15.8M/26.0M [00:01<00:00, 15.5M Bytes/s]
# Get sub-05/s .. _bold.nii.gz:  72%|██▏| 18.8M/26.0M [00:01<00:00, 15.1M Bytes/s]
# Get sub-05/s .. _bold.nii.gz:  79%|██▎| 20.5M/26.0M [00:01<00:00, 15.6M Bytes/s]
# Get sub-05/s .. _bold.nii.gz:  85%|██▌| 22.1M/26.0M [00:01<00:00, 15.7M Bytes/s]
# Get sub-05/s .. _bold.nii.gz:  92%|██▋| 23.8M/26.0M [00:01<00:00, 15.7M Bytes/s]
# Total:  47%|████████████▏             | 1.01G/2.17G [01:06<01:16, 15.2M Bytes/s]
# Get sub-05/s .. _bold.nii.gz:   0%|            | 0.00/33.6M [00:00<?, ? Bytes/s]
# Get sub-05/s .. _bold.nii.gz:  10%|▎  | 3.30M/33.6M [00:00<00:01, 16.5M Bytes/s]
# Get sub-05/s .. _bold.nii.gz:  15%|▍  | 4.95M/33.6M [00:00<00:01, 16.2M Bytes/s]
# Get sub-05/s .. _bold.nii.gz:  25%|▊  | 8.56M/33.6M [00:00<00:01, 17.2M Bytes/s]
# Get sub-05/s .. _bold.nii.gz:  31%|▉  | 10.3M/33.6M [00:00<00:01, 17.1M Bytes/s]
# Get sub-05/s .. _bold.nii.gz:  41%|█▏ | 13.8M/33.6M [00:00<00:01, 17.1M Bytes/s]
# Get sub-05/s .. _bold.nii.gz:  51%|█▌ | 17.2M/33.6M [00:01<00:00, 17.1M Bytes/s]
# Get sub-05/s .. _bold.nii.gz:  57%|█▋ | 19.0M/33.6M [00:01<00:00, 17.4M Bytes/s]
# Get sub-05/s .. _bold.nii.gz:  67%|██ | 22.4M/33.6M [00:01<00:00, 17.1M Bytes/s]
# Get sub-05/s .. _bold.nii.gz:  72%|██▏| 24.2M/33.6M [00:01<00:00, 17.3M Bytes/s]
# Get sub-05/s .. _bold.nii.gz:  78%|██▎| 26.1M/33.6M [00:01<00:00, 17.6M Bytes/s]
# Get sub-05/s .. _bold.nii.gz:  83%|██▌| 28.0M/33.6M [00:01<00:00, 18.0M Bytes/s]
# Get sub-05/s .. _bold.nii.gz:  94%|██▊| 31.5M/33.6M [00:01<00:00, 17.7M Bytes/s]
# Total:  48%|████████████▌             | 1.05G/2.17G [01:09<01:14, 15.2M Bytes/s]
# Get sub-05/s .. _bold.nii.gz:   0%|            | 0.00/12.9M [00:00<?, ? Bytes/s]
# Get sub-05/s .. _bold.nii.gz:  29%|▊  | 3.70M/12.9M [00:00<00:00, 18.5M Bytes/s]
# Get sub-05/s .. _bold.nii.gz:  43%|█▎ | 5.59M/12.9M [00:00<00:00, 18.7M Bytes/s]
# Get sub-05/s .. _bold.nii.gz:  72%|██▏| 9.33M/12.9M [00:00<00:00, 18.6M Bytes/s]
# Get sub-05/s .. _bold.nii.gz:  87%|██▌| 11.2M/12.9M [00:00<00:00, 18.7M Bytes/s]
#
# Get sub-05/s .. _bold.nii.gz:   0%|            | 0.00/11.1M [00:00<?, ? Bytes/s]
# Get sub-05/s .. _bold.nii.gz:  34%|█  | 3.73M/11.1M [00:00<00:00, 18.2M Bytes/s]
# Get sub-05/s .. _bold.nii.gz:  52%|█▌ | 5.74M/11.1M [00:00<00:00, 19.0M Bytes/s]
# Get sub-05/s .. _bold.nii.gz:  85%|██▌| 9.46M/11.1M [00:00<00:00, 18.7M Bytes/s]
#
# Get sub-05/s .. t_T1w.nii.gz:   0%|            | 0.00/9.94M [00:00<?, ? Bytes/s]
# Get sub-05/s .. t_T1w.nii.gz:  39%|█▏ | 3.91M/9.94M [00:00<00:00, 19.6M Bytes/s]
# Get sub-05/s .. t_T1w.nii.gz:  79%|██▎| 7.84M/9.94M [00:00<00:00, 19.6M Bytes/s]
# Get sub-05/s .. t_T1w.nii.gz:  99%|██▉| 9.82M/9.94M [00:00<00:00, 19.6M Bytes/s]
# Total:  50%|████████████▉             | 1.08G/2.17G [01:11<01:12, 15.1M Bytes/s]
# Get sub-05/s .. t_dwi.nii.gz:   0%|             | 0.00/108M [00:00<?, ? Bytes/s]
# Get sub-05/s .. t_dwi.nii.gz:   4%|▏   | 3.89M/108M [00:00<00:05, 19.4M Bytes/s]
# Get sub-05/s .. t_dwi.nii.gz:   5%|▏   | 5.89M/108M [00:00<00:05, 19.6M Bytes/s]
# Get sub-05/s .. t_dwi.nii.gz:   9%|▎   | 9.89M/108M [00:00<00:04, 19.8M Bytes/s]
# Get sub-05/s .. t_dwi.nii.gz:  11%|▍   | 11.9M/108M [00:00<00:04, 19.9M Bytes/s]
# Get sub-05/s .. t_dwi.nii.gz:  13%|▌   | 13.9M/108M [00:00<00:04, 19.9M Bytes/s]
# Get sub-05/s .. t_dwi.nii.gz:  16%|▋   | 17.7M/108M [00:00<00:04, 19.5M Bytes/s]
# Get sub-05/s .. t_dwi.nii.gz:  18%|▋   | 19.8M/108M [00:01<00:04, 19.8M Bytes/s]
# Get sub-05/s .. t_dwi.nii.gz:  22%|▉   | 23.7M/108M [00:01<00:04, 19.8M Bytes/s]
# Get sub-05/s .. t_dwi.nii.gz:  24%|▉   | 25.9M/108M [00:01<00:04, 20.2M Bytes/s]
# Get sub-05/s .. t_dwi.nii.gz:  27%|█   | 29.5M/108M [00:01<00:04, 19.3M Bytes/s]
# Get sub-05/s .. t_dwi.nii.gz:  31%|█▎  | 33.8M/108M [00:01<00:03, 20.0M Bytes/s]
# Get sub-05/s .. t_dwi.nii.gz:  35%|█▍  | 37.9M/108M [00:01<00:03, 19.8M Bytes/s]
# Get sub-05/s .. t_dwi.nii.gz:  39%|█▌  | 41.9M/108M [00:02<00:03, 19.4M Bytes/s]
# Get sub-05/s .. t_dwi.nii.gz:  42%|█▋  | 45.1M/108M [00:02<00:03, 19.3M Bytes/s]
# Get sub-05/s .. t_dwi.nii.gz:  44%|█▊  | 48.0M/108M [00:02<00:03, 20.0M Bytes/s]
# Get sub-05/s .. t_dwi.nii.gz:  48%|█▉  | 52.1M/108M [00:02<00:02, 20.1M Bytes/s]
# Get sub-05/s .. t_dwi.nii.gz:  50%|██  | 54.2M/108M [00:02<00:02, 20.2M Bytes/s]
# Get sub-05/s .. t_dwi.nii.gz:  54%|██▏ | 58.2M/108M [00:02<00:02, 20.0M Bytes/s]
# Get sub-05/s .. t_dwi.nii.gz:  56%|██▏ | 60.3M/108M [00:03<00:02, 20.1M Bytes/s]
# Get sub-05/s .. t_dwi.nii.gz:  58%|██▎ | 62.4M/108M [00:03<00:02, 20.0M Bytes/s]
# Get sub-05/s .. t_dwi.nii.gz:  61%|██▍ | 65.6M/108M [00:03<00:02, 20.2M Bytes/s]
# Get sub-05/s .. t_dwi.nii.gz:  63%|██▌ | 68.5M/108M [00:03<00:01, 20.2M Bytes/s]
# Get sub-05/s .. t_dwi.nii.gz:  67%|██▋ | 72.5M/108M [00:03<00:01, 20.0M Bytes/s]
# Get sub-05/s .. t_dwi.nii.gz:  69%|██▊ | 74.8M/108M [00:03<00:01, 19.7M Bytes/s]
# Get sub-05/s .. t_dwi.nii.gz:  71%|██▊ | 76.8M/108M [00:03<00:01, 19.9M Bytes/s]
# Get sub-05/s .. t_dwi.nii.gz:  73%|██▉ | 78.9M/108M [00:03<00:01, 20.1M Bytes/s]
# Get sub-05/s .. t_dwi.nii.gz:  75%|██▉ | 81.0M/108M [00:04<00:01, 20.2M Bytes/s]
# Get sub-05/s .. t_dwi.nii.gz:  77%|███ | 83.0M/108M [00:04<00:01, 20.2M Bytes/s]
# Get sub-05/s .. t_dwi.nii.gz:  79%|███▏| 85.8M/108M [00:04<00:01, 20.6M Bytes/s]
# Get sub-05/s .. t_dwi.nii.gz:  82%|███▎| 89.0M/108M [00:04<00:00, 19.9M Bytes/s]
# Get sub-05/s .. t_dwi.nii.gz:  84%|███▍| 91.2M/108M [00:04<00:00, 20.5M Bytes/s]
# Get sub-05/s .. t_dwi.nii.gz:  88%|███▌| 95.3M/108M [00:04<00:00, 20.5M Bytes/s]
# Get sub-05/s .. t_dwi.nii.gz:  92%|███▋| 99.3M/108M [00:04<00:00, 20.1M Bytes/s]
# Get sub-05/s .. t_dwi.nii.gz:  94%|████▋| 102M/108M [00:05<00:00, 20.6M Bytes/s]
# Get sub-05/s .. t_dwi.nii.gz:  98%|████▉| 105M/108M [00:05<00:00, 20.2M Bytes/s]
# Total:  55%|██████████████▏           | 1.19G/2.17G [01:17<01:04, 15.3M Bytes/s]
# Get sub-05/s .. _bold.nii.gz:   0%|            | 0.00/24.9M [00:00<?, ? Bytes/s]
# Get sub-05/s .. _bold.nii.gz:  15%|▍  | 3.86M/24.9M [00:00<00:01, 19.2M Bytes/s]
# Get sub-05/s .. _bold.nii.gz:  24%|▋  | 6.03M/24.9M [00:00<00:00, 20.3M Bytes/s]
# Get sub-05/s .. _bold.nii.gz:  41%|█▏ | 10.2M/24.9M [00:00<00:00, 20.5M Bytes/s]
# Get sub-05/s .. _bold.nii.gz:  56%|█▋ | 14.0M/24.9M [00:00<00:00, 19.9M Bytes/s]
# Get sub-05/s .. _bold.nii.gz:  71%|██▏| 17.7M/24.9M [00:00<00:00, 19.3M Bytes/s]
# Get sub-05/s .. _bold.nii.gz:  87%|██▌| 21.8M/24.9M [00:01<00:00, 19.6M Bytes/s]
# Get sub-05/s .. _bold.nii.gz:  95%|██▊| 23.8M/24.9M [00:01<00:00, 19.7M Bytes/s]
#
# Get sub-05/s .. _bold.nii.gz:   0%|            | 0.00/26.7M [00:00<?, ? Bytes/s]
# Get sub-05/s .. _bold.nii.gz:  15%|▍  | 4.06M/26.7M [00:00<00:01, 20.3M Bytes/s]
# Get sub-05/s .. _bold.nii.gz:  23%|▋  | 6.14M/26.7M [00:00<00:01, 20.5M Bytes/s]
# Get sub-05/s .. _bold.nii.gz:  38%|█▏ | 10.2M/26.7M [00:00<00:00, 20.3M Bytes/s]
# Get sub-05/s .. _bold.nii.gz:  46%|█▍ | 12.3M/26.7M [00:00<00:00, 20.2M Bytes/s]
# Get sub-05/s .. _bold.nii.gz:  54%|█▋ | 14.5M/26.7M [00:00<00:00, 20.7M Bytes/s]
# Get sub-05/s .. _bold.nii.gz:  69%|██ | 18.4M/26.7M [00:00<00:00, 20.1M Bytes/s]
# Get sub-05/s .. _bold.nii.gz:  77%|██▎| 20.6M/26.7M [00:01<00:00, 20.4M Bytes/s]
# Get sub-05/s .. _bold.nii.gz:  86%|██▌| 22.9M/26.7M [00:01<00:00, 20.9M Bytes/s]
# Get sub-05/s .. _bold.nii.gz: 100%|██▉| 26.7M/26.7M [00:01<00:00, 20.3M Bytes/s]
#
# Get sub-05/s .. _bold.nii.gz:   0%|            | 0.00/34.4M [00:00<?, ? Bytes/s]
# Get sub-05/s .. _bold.nii.gz:  12%|▎  | 4.12M/34.4M [00:00<00:01, 20.5M Bytes/s]
# Get sub-05/s .. _bold.nii.gz:  18%|▌  | 6.18M/34.4M [00:00<00:01, 20.5M Bytes/s]
# Get sub-05/s .. _bold.nii.gz:  24%|▋  | 8.26M/34.4M [00:00<00:01, 20.6M Bytes/s]
# Get sub-05/s .. _bold.nii.gz:  36%|█  | 12.3M/34.4M [00:00<00:01, 20.2M Bytes/s]
# Get sub-05/s .. _bold.nii.gz:  42%|█▎ | 14.5M/34.4M [00:00<00:00, 20.7M Bytes/s]
# Get sub-05/s .. _bold.nii.gz:  54%|█▋ | 18.7M/34.4M [00:00<00:00, 20.7M Bytes/s]
# Get sub-05/s .. _bold.nii.gz:  66%|█▉ | 22.6M/34.4M [00:01<00:00, 20.4M Bytes/s]
# Get sub-05/s .. _bold.nii.gz:  72%|██▏| 24.7M/34.4M [00:01<00:00, 20.5M Bytes/s]
# Get sub-05/s .. _bold.nii.gz:  78%|██▎| 26.9M/34.4M [00:01<00:00, 20.5M Bytes/s]
# Get sub-05/s .. _bold.nii.gz:  89%|██▋| 30.6M/34.4M [00:01<00:00, 19.9M Bytes/s]
# Get sub-05/s .. _bold.nii.gz:  95%|██▊| 32.7M/34.4M [00:01<00:00, 20.0M Bytes/s]
#
# Get sub-05/s .. _bold.nii.gz:   0%|            | 0.00/13.1M [00:00<?, ? Bytes/s]
# Get sub-05/s .. _bold.nii.gz:  30%|▉  | 3.97M/13.1M [00:00<00:00, 19.8M Bytes/s]
# Get sub-05/s .. _bold.nii.gz:  47%|█▍ | 6.21M/13.1M [00:00<00:00, 20.9M Bytes/s]
# Get sub-05/s .. _bold.nii.gz:  78%|██▎| 10.3M/13.1M [00:00<00:00, 20.6M Bytes/s]
#
# Get sub-05/s .. _bold.nii.gz:   0%|            | 0.00/11.5M [00:00<?, ? Bytes/s]
# Get sub-05/s .. _bold.nii.gz:  17%|▌  | 2.00M/11.5M [00:00<00:00, 20.0M Bytes/s]
# Get sub-05/s .. _bold.nii.gz:  35%|█  | 4.04M/11.5M [00:00<00:00, 20.2M Bytes/s]
# Get sub-05/s .. _bold.nii.gz:  53%|█▌ | 6.12M/11.5M [00:00<00:00, 20.0M Bytes/s]
# Get sub-05/s .. _bold.nii.gz:  90%|██▋| 10.4M/11.5M [00:00<00:00, 20.6M Bytes/s]
# Total:  60%|███████████████▌          | 1.30G/2.17G [01:24<00:56, 15.3M Bytes/s]
# Get sub-03/s .. t_T1w.nii.gz:   0%|            | 0.00/8.13M [00:00<?, ? Bytes/s]
# Get sub-03/s .. t_T1w.nii.gz:  22%|▋  | 1.81M/8.13M [00:00<00:00, 16.7M Bytes/s]
# Get sub-03/s .. t_T1w.nii.gz:  58%|█▋ | 4.72M/8.13M [00:00<00:00, 15.3M Bytes/s]
# Get sub-03/s .. t_T1w.nii.gz:  85%|██▌| 6.91M/8.13M [00:00<00:00, 17.4M Bytes/s]
#
# Get sub-03/s .. t_dwi.nii.gz:   0%|             | 0.00/102M [00:00<?, ? Bytes/s]
# Get sub-03/s .. t_dwi.nii.gz:   3%|▏   | 3.20M/102M [00:00<00:06, 16.0M Bytes/s]
# Get sub-03/s .. t_dwi.nii.gz:   6%|▎   | 6.55M/102M [00:00<00:05, 16.2M Bytes/s]
# Get sub-03/s .. t_dwi.nii.gz:  10%|▍   | 9.97M/102M [00:00<00:05, 16.4M Bytes/s]
# Get sub-03/s .. t_dwi.nii.gz:  11%|▍   | 11.7M/102M [00:00<00:05, 16.6M Bytes/s]
# Get sub-03/s .. t_dwi.nii.gz:  13%|▌   | 13.3M/102M [00:00<00:05, 16.6M Bytes/s]
# Get sub-03/s .. t_dwi.nii.gz:  15%|▌   | 15.0M/102M [00:00<00:05, 16.6M Bytes/s]
# Get sub-03/s .. t_dwi.nii.gz:  18%|▋   | 18.3M/102M [00:01<00:05, 16.4M Bytes/s]
# Get sub-03/s .. t_dwi.nii.gz:  21%|▊   | 21.1M/102M [00:01<00:04, 16.6M Bytes/s]
# Get sub-03/s .. t_dwi.nii.gz:  23%|▉   | 23.4M/102M [00:01<00:04, 16.7M Bytes/s]
# Get sub-03/s .. t_dwi.nii.gz:  27%|█   | 27.1M/102M [00:01<00:04, 16.7M Bytes/s]
# Get sub-03/s .. t_dwi.nii.gz:  28%|█▏  | 28.8M/102M [00:01<00:04, 16.9M Bytes/s]
# Get sub-03/s .. t_dwi.nii.gz:  30%|█▏  | 30.7M/102M [00:01<00:04, 17.1M Bytes/s]
# Get sub-03/s .. t_dwi.nii.gz:  32%|█▎  | 32.5M/102M [00:01<00:03, 17.4M Bytes/s]
# Get sub-03/s .. t_dwi.nii.gz:  34%|█▎  | 34.3M/102M [00:02<00:03, 17.6M Bytes/s]
# Get sub-03/s .. t_dwi.nii.gz:  37%|█▍  | 37.3M/102M [00:02<00:03, 16.4M Bytes/s]
# Get sub-03/s .. t_dwi.nii.gz:  39%|█▌  | 39.6M/102M [00:02<00:04, 14.3M Bytes/s]
# Get sub-03/s .. t_dwi.nii.gz:  41%|█▌  | 41.3M/102M [00:02<00:04, 14.9M Bytes/s]
# Get sub-03/s .. t_dwi.nii.gz:  43%|█▋  | 43.5M/102M [00:02<00:03, 16.5M Bytes/s]
# Get sub-03/s .. t_dwi.nii.gz:  45%|█▊  | 45.8M/102M [00:02<00:03, 18.2M Bytes/s]
# Get sub-03/s .. t_dwi.nii.gz:  49%|█▉  | 50.2M/102M [00:02<00:02, 19.8M Bytes/s]
# Get sub-03/s .. t_dwi.nii.gz:  53%|██▏ | 54.1M/102M [00:03<00:02, 19.6M Bytes/s]
# Get sub-03/s .. t_dwi.nii.gz:  55%|██▏ | 56.3M/102M [00:03<00:02, 18.6M Bytes/s]
# Get sub-03/s .. t_dwi.nii.gz:  59%|██▎ | 59.9M/102M [00:03<00:02, 19.1M Bytes/s]
# Get sub-03/s .. t_dwi.nii.gz:  61%|██▍ | 61.8M/102M [00:03<00:02, 19.2M Bytes/s]
# Get sub-03/s .. t_dwi.nii.gz:  63%|██▌ | 63.8M/102M [00:03<00:01, 19.3M Bytes/s]
# Get sub-03/s .. t_dwi.nii.gz:  65%|██▌ | 65.8M/102M [00:03<00:01, 18.4M Bytes/s]
# Get sub-03/s .. t_dwi.nii.gz:  67%|██▋ | 68.1M/102M [00:03<00:02, 16.3M Bytes/s]
# Get sub-03/s .. t_dwi.nii.gz:  69%|██▋ | 69.9M/102M [00:04<00:01, 16.6M Bytes/s]
# Get sub-03/s .. t_dwi.nii.gz:  72%|██▊ | 72.8M/102M [00:04<00:01, 15.9M Bytes/s]
# ...
# Get sub-04/s .. t_dwi.nii.gz:  33%|█▎  | 33.6M/102M [00:02<00:07, 9.77M Bytes/s]
# Get sub-04/s .. t_dwi.nii.gz:  34%|█▎  | 34.6M/102M [00:03<00:06, 9.91M Bytes/s]
# Get sub-04/s .. t_dwi.nii.gz:  35%|█▍  | 35.6M/102M [00:03<00:06, 9.84M Bytes/s]
# Get sub-04/s .. t_dwi.nii.gz:  36%|█▍  | 37.0M/102M [00:03<00:06, 10.1M Bytes/s]
# Get sub-04/s .. t_dwi.nii.gz:  38%|█▌  | 38.5M/102M [00:03<00:06, 9.45M Bytes/s]
# Get sub-04/s .. t_dwi.nii.gz:  39%|█▌  | 39.5M/102M [00:03<00:06, 9.48M Bytes/s]
# Get sub-04/s .. t_dwi.nii.gz:  40%|█▌  | 40.6M/102M [00:03<00:06, 9.84M Bytes/s]
# Get sub-04/s .. t_dwi.nii.gz:  41%|█▋  | 41.7M/102M [00:03<00:06, 9.60M Bytes/s]
# Get sub-04/s .. t_dwi.nii.gz:  43%|█▋  | 43.6M/102M [00:03<00:05, 10.0M Bytes/s]
# Get sub-04/s .. t_dwi.nii.gz:  45%|█▊  | 45.5M/102M [00:04<00:05, 9.86M Bytes/s]
# Get sub-04/s .. t_dwi.nii.gz:  46%|█▊  | 46.7M/102M [00:04<00:05, 9.68M Bytes/s]
# Get sub-04/s .. t_dwi.nii.gz:  47%|█▉  | 48.4M/102M [00:04<00:05, 9.60M Bytes/s]
# Get sub-04/s .. t_dwi.nii.gz:  48%|█▉  | 49.4M/102M [00:04<00:05, 9.64M Bytes/s]
# Get sub-04/s .. t_dwi.nii.gz:  50%|██  | 51.3M/102M [00:04<00:05, 9.60M Bytes/s]
# Get sub-04/s .. t_dwi.nii.gz:  52%|██  | 53.3M/102M [00:04<00:04, 11.7M Bytes/s]
# Get sub-04/s .. t_dwi.nii.gz:  55%|██▏ | 55.8M/102M [00:04<00:03, 14.9M Bytes/s]
# Get sub-04/s .. t_dwi.nii.gz:  57%|██▎ | 58.1M/102M [00:05<00:02, 16.9M Bytes/s]
# Get sub-04/s .. t_dwi.nii.gz:  59%|██▎ | 60.2M/102M [00:05<00:02, 17.9M Bytes/s]
# Get sub-04/s .. t_dwi.nii.gz:  61%|██▍ | 62.2M/102M [00:05<00:02, 18.4M Bytes/s]
# Get sub-04/s .. t_dwi.nii.gz:  63%|██▌ | 64.6M/102M [00:05<00:02, 15.3M Bytes/s]
# Get sub-04/s .. t_dwi.nii.gz:  65%|██▌ | 66.5M/102M [00:05<00:02, 13.0M Bytes/s]
# Get sub-04/s .. t_dwi.nii.gz:  67%|██▋ | 68.6M/102M [00:05<00:02, 12.0M Bytes/s]
# Get sub-04/s .. t_dwi.nii.gz:  70%|██▊ | 72.1M/102M [00:06<00:02, 13.8M Bytes/s]
# Get sub-04/s .. t_dwi.nii.gz:  73%|██▉ | 74.7M/102M [00:06<00:01, 16.3M Bytes/s]
# Get sub-04/s .. t_dwi.nii.gz:  76%|███ | 77.4M/102M [00:06<00:01, 18.4M Bytes/s]
# Get sub-04/s .. t_dwi.nii.gz:  78%|███ | 79.5M/102M [00:06<00:01, 19.0M Bytes/s]
# Get sub-04/s .. t_dwi.nii.gz:  80%|███▏| 82.1M/102M [00:06<00:01, 13.7M Bytes/s]
# Get sub-04/s .. t_dwi.nii.gz:  83%|███▎| 84.4M/102M [00:06<00:01, 13.1M Bytes/s]
# Get sub-04/s .. t_dwi.nii.gz:  85%|███▍| 86.9M/102M [00:07<00:01, 15.3M Bytes/s]
# Get sub-04/s .. t_dwi.nii.gz:  87%|███▍| 89.5M/102M [00:07<00:00, 17.4M Bytes/s]
# Get sub-04/s .. t_dwi.nii.gz:  90%|███▌| 92.2M/102M [00:07<00:00, 19.7M Bytes/s]
# Get sub-04/s .. t_dwi.nii.gz:  94%|███▊| 96.2M/102M [00:07<00:00, 19.8M Bytes/s]
# Get sub-04/s .. t_dwi.nii.gz:  98%|████▉| 100M/102M [00:07<00:00, 19.9M Bytes/s]
#
# Get sub-04/s .. t_dwi.nii.gz:   0%|             | 0.00/102M [00:00<?, ? Bytes/s]
# Total:  85%|██████████████████████    | 1.84G/2.17G [02:04<00:22, 14.8M Bytes/s]
# Get sub-04/s .. _bold.nii.gz:   0%|            | 0.00/24.6M [00:00<?, ? Bytes/s]
# Get sub-04/s .. _bold.nii.gz:   7%|▏  | 1.75M/24.6M [00:00<00:01, 16.6M Bytes/s]
# Get sub-04/s .. _bold.nii.gz:  16%|▍  | 4.03M/24.6M [00:00<00:01, 20.1M Bytes/s]
# Get sub-04/s .. _bold.nii.gz:  28%|▊  | 6.83M/24.6M [00:00<00:01, 16.2M Bytes/s]
# Get sub-04/s .. _bold.nii.gz:  40%|█▏ | 9.81M/24.6M [00:00<00:00, 15.6M Bytes/s]
# Get sub-04/s .. _bold.nii.gz:  52%|█▌ | 12.7M/24.6M [00:00<00:00, 15.2M Bytes/s]
# Get sub-04/s .. _bold.nii.gz:  64%|█▉ | 15.8M/24.6M [00:01<00:00, 15.3M Bytes/s]
# Get sub-04/s .. _bold.nii.gz:  71%|██▏| 17.6M/24.6M [00:01<00:00, 15.7M Bytes/s]
# Get sub-04/s .. _bold.nii.gz:  83%|██▌| 20.5M/24.6M [00:01<00:00, 15.4M Bytes/s]
# Get sub-04/s .. _bold.nii.gz:  91%|██▋| 22.4M/24.6M [00:01<00:00, 15.0M Bytes/s]
# Get sub-04/s .. _bold.nii.gz:  97%|██▉| 24.0M/24.6M [00:01<00:00, 15.2M Bytes/s]
#
# Get sub-04/s .. _bold.nii.gz:   0%|            | 0.00/26.2M [00:00<?, ? Bytes/s]
# Get sub-04/s .. _bold.nii.gz:   6%|▏  | 1.67M/26.2M [00:00<00:01, 16.7M Bytes/s]
# Get sub-04/s .. _bold.nii.gz:  18%|▌  | 4.67M/26.2M [00:00<00:01, 17.1M Bytes/s]
# Get sub-04/s .. _bold.nii.gz:  26%|▊  | 6.70M/26.2M [00:00<00:01, 16.6M Bytes/s]
# Get sub-04/s .. _bold.nii.gz:  38%|█▏ | 9.98M/26.2M [00:00<00:00, 16.5M Bytes/s]
# Get sub-04/s .. _bold.nii.gz:  44%|█▎ | 11.6M/26.2M [00:00<00:00, 16.5M Bytes/s]
# Get sub-04/s .. _bold.nii.gz:  52%|█▌ | 13.6M/26.2M [00:00<00:00, 17.3M Bytes/s]
# Get sub-04/s .. _bold.nii.gz:  59%|█▊ | 15.4M/26.2M [00:00<00:00, 17.4M Bytes/s]
# Get sub-04/s .. _bold.nii.gz:  72%|██▏| 18.8M/26.2M [00:01<00:00, 17.4M Bytes/s]
# Get sub-04/s .. _bold.nii.gz:  79%|██▎| 20.6M/26.2M [00:01<00:00, 17.5M Bytes/s]
# Get sub-04/s .. _bold.nii.gz:  92%|██▊| 24.2M/26.2M [00:01<00:00, 17.5M Bytes/s]
# Get sub-04/s .. _bold.nii.gz:  99%|██▉| 26.0M/26.2M [00:01<00:00, 17.8M Bytes/s]
#
# Get sub-04/s .. _bold.nii.gz:   0%|            | 0.00/33.7M [00:00<?, ? Bytes/s]
# Get sub-04/s .. _bold.nii.gz:  11%|▎  | 3.60M/33.7M [00:00<00:01, 18.0M Bytes/s]
# Get sub-04/s .. _bold.nii.gz:  16%|▍  | 5.45M/33.7M [00:00<00:01, 18.2M Bytes/s]
# Get sub-04/s .. _bold.nii.gz:  27%|▊  | 9.14M/33.7M [00:00<00:01, 18.3M Bytes/s]
# Get sub-04/s .. _bold.nii.gz:  38%|█▏ | 12.7M/33.7M [00:00<00:01, 18.1M Bytes/s]
# Get sub-04/s .. _bold.nii.gz:  49%|█▍ | 16.5M/33.7M [00:00<00:00, 18.2M Bytes/s]
# Get sub-04/s .. _bold.nii.gz:  55%|█▋ | 18.5M/33.7M [00:01<00:00, 18.6M Bytes/s]
# Get sub-04/s .. _bold.nii.gz:  60%|█▊ | 20.4M/33.7M [00:01<00:00, 18.7M Bytes/s]
# Get sub-04/s .. _bold.nii.gz:  66%|█▉ | 22.3M/33.7M [00:01<00:00, 18.7M Bytes/s]
# Get sub-04/s .. _bold.nii.gz:  77%|██▎| 26.0M/33.7M [00:01<00:00, 18.7M Bytes/s]
# Get sub-04/s .. _bold.nii.gz:  83%|██▍| 28.0M/33.7M [00:01<00:00, 18.9M Bytes/s]
# Get sub-04/s .. _bold.nii.gz:  89%|██▋| 29.9M/33.7M [00:01<00:00, 19.0M Bytes/s]
# Get sub-04/s .. _bold.nii.gz:  97%|██▉| 32.8M/33.7M [00:01<00:00, 18.2M Bytes/s]
#
# Get sub-04/s .. _bold.nii.gz:   0%|            | 0.00/12.9M [00:00<?, ? Bytes/s]
# Get sub-04/s .. _bold.nii.gz:  27%|▊  | 3.50M/12.9M [00:00<00:00, 17.5M Bytes/s]
# Get sub-04/s .. _bold.nii.gz:  42%|█▎ | 5.37M/12.9M [00:00<00:00, 18.0M Bytes/s]
# Get sub-04/s .. _bold.nii.gz:  58%|█▋ | 7.42M/12.9M [00:00<00:00, 18.3M Bytes/s]
# Get sub-04/s .. _bold.nii.gz:  72%|██▏| 9.32M/12.9M [00:00<00:00, 18.5M Bytes/s]
# Get sub-04/s .. _bold.nii.gz:  88%|██▋| 11.3M/12.9M [00:00<00:00, 18.8M Bytes/s]
#
# Get sub-04/s .. _bold.nii.gz:   0%|            | 0.00/11.2M [00:00<?, ? Bytes/s]
# Get sub-04/s .. _bold.nii.gz:  35%|█  | 3.93M/11.2M [00:00<00:00, 20.9M Bytes/s]
# Get sub-04/s .. _bold.nii.gz:  70%|██ | 7.87M/11.2M [00:00<00:00, 20.2M Bytes/s]
# Total:  90%|███████████████████████▎  | 1.95G/2.17G [02:12<00:15, 14.7M Bytes/s]
# Get sub-04/s .. t_T1w.nii.gz:   0%|            | 0.00/9.72M [00:00<?, ? Bytes/s]
# Get sub-04/s .. t_T1w.nii.gz:  40%|█▏ | 3.93M/9.72M [00:00<00:00, 19.6M Bytes/s]
# Get sub-04/s .. t_T1w.nii.gz:  61%|█▊ | 5.92M/9.72M [00:00<00:00, 19.7M Bytes/s]
#
# Get sub-04/s .. t_dwi.nii.gz:   0%|             | 0.00/105M [00:00<?, ? Bytes/s]
# Get sub-04/s .. t_dwi.nii.gz:   4%|▏   | 3.96M/105M [00:00<00:05, 19.7M Bytes/s]
# Get sub-04/s .. t_dwi.nii.gz:   8%|▎   | 7.95M/105M [00:00<00:04, 19.9M Bytes/s]
# Get sub-04/s .. t_dwi.nii.gz:  10%|▍   | 9.97M/105M [00:00<00:04, 19.9M Bytes/s]
# Get sub-04/s .. t_dwi.nii.gz:  13%|▌   | 13.9M/105M [00:00<00:04, 19.9M Bytes/s]
# Get sub-04/s .. t_dwi.nii.gz:  17%|▋   | 18.0M/105M [00:00<00:04, 20.0M Bytes/s]
# Get sub-04/s .. t_dwi.nii.gz:  19%|▊   | 20.0M/105M [00:01<00:04, 20.0M Bytes/s]
# Get sub-04/s .. t_dwi.nii.gz:  23%|▉   | 23.9M/105M [00:01<00:04, 19.8M Bytes/s]
# Get sub-04/s .. t_dwi.nii.gz:  26%|█   | 27.6M/105M [00:01<00:04, 19.3M Bytes/s]
# Get sub-04/s .. t_dwi.nii.gz:  28%|█▏  | 29.7M/105M [00:01<00:03, 19.7M Bytes/s]
# Get sub-04/s .. t_dwi.nii.gz:  30%|█▏  | 31.8M/105M [00:01<00:03, 19.9M Bytes/s]
# Get sub-04/s .. t_dwi.nii.gz:  32%|█▎  | 34.1M/105M [00:01<00:03, 19.6M Bytes/s]
# Get sub-04/s .. t_dwi.nii.gz:  34%|█▍  | 36.1M/105M [00:01<00:03, 19.7M Bytes/s]
# Get sub-04/s .. t_dwi.nii.gz:  38%|█▌  | 40.1M/105M [00:02<00:03, 19.7M Bytes/s]
# Get sub-04/s .. t_dwi.nii.gz:  40%|█▌  | 42.1M/105M [00:02<00:03, 19.8M Bytes/s]
# Get sub-04/s .. t_dwi.nii.gz:  43%|█▋  | 45.5M/105M [00:02<00:02, 20.2M Bytes/s]
# Get sub-04/s .. t_dwi.nii.gz:  46%|█▊  | 48.1M/105M [00:02<00:02, 19.8M Bytes/s]
# Get sub-04/s .. t_dwi.nii.gz:  48%|█▉  | 50.1M/105M [00:02<00:02, 19.9M Bytes/s]
# Get sub-04/s .. t_dwi.nii.gz:  50%|█▉  | 52.2M/105M [00:02<00:02, 20.0M Bytes/s]
# Get sub-04/s .. t_dwi.nii.gz:  52%|██  | 54.2M/105M [00:02<00:02, 20.0M Bytes/s]
# Get sub-04/s .. t_dwi.nii.gz:  54%|██▏ | 56.2M/105M [00:02<00:02, 20.1M Bytes/s]
# Get sub-04/s .. t_dwi.nii.gz:  57%|██▎ | 60.3M/105M [00:03<00:02, 20.1M Bytes/s]
# Get sub-04/s .. t_dwi.nii.gz:  59%|██▍ | 62.3M/105M [00:03<00:02, 20.2M Bytes/s]
# Get sub-04/s .. t_dwi.nii.gz:  61%|██▍ | 64.3M/105M [00:03<00:02, 20.2M Bytes/s]
# Get sub-04/s .. t_dwi.nii.gz:  65%|██▌ | 67.9M/105M [00:03<00:01, 19.1M Bytes/s]
# Get sub-04/s .. t_dwi.nii.gz:  67%|██▋ | 70.4M/105M [00:03<00:01, 19.8M Bytes/s]
# Get sub-04/s .. t_dwi.nii.gz:  71%|██▊ | 74.3M/105M [00:03<00:01, 19.5M Bytes/s]
# Get sub-04/s .. t_dwi.nii.gz:  73%|██▉ | 76.3M/105M [00:03<00:01, 19.6M Bytes/s]
# Get sub-04/s .. t_dwi.nii.gz:  77%|███ | 80.3M/105M [00:04<00:01, 19.2M Bytes/s]
# Get sub-04/s .. t_dwi.nii.gz:  78%|███▏| 82.3M/105M [00:04<00:01, 15.3M Bytes/s]
# Get sub-04/s .. t_dwi.nii.gz:  81%|███▏| 84.6M/105M [00:04<00:01, 14.5M Bytes/s]
# Get sub-04/s .. t_dwi.nii.gz:  82%|███▎| 86.5M/105M [00:04<00:01, 12.7M Bytes/s]
# Get sub-04/s .. t_dwi.nii.gz:  84%|███▎| 88.4M/105M [00:04<00:01, 11.5M Bytes/s]
# Get sub-04/s .. t_dwi.nii.gz:  86%|███▍| 90.0M/105M [00:05<00:01, 10.4M Bytes/s]
# Get sub-04/s .. t_dwi.nii.gz:  87%|███▍| 91.4M/105M [00:05<00:01, 10.8M Bytes/s]
# Get sub-04/s .. t_dwi.nii.gz:  89%|███▌| 93.3M/105M [00:05<00:01, 10.4M Bytes/s]
# Get sub-04/s .. t_dwi.nii.gz:  90%|███▌| 94.8M/105M [00:05<00:00, 11.2M Bytes/s]
# Get sub-04/s .. t_dwi.nii.gz:  92%|███▋| 96.2M/105M [00:05<00:00, 11.5M Bytes/s]
# Get sub-04/s .. t_dwi.nii.gz:  93%|███▋| 97.8M/105M [00:05<00:00, 10.7M Bytes/s]
# Get sub-04/s .. t_dwi.nii.gz:  94%|███▊| 99.0M/105M [00:05<00:00, 10.3M Bytes/s]
# Get sub-04/s .. t_dwi.nii.gz:  96%|████▊| 100M/105M [00:06<00:00, 10.8M Bytes/s]
# Get sub-04/s .. t_dwi.nii.gz:  97%|████▊| 102M/105M [00:06<00:00, 9.91M Bytes/s]
# Get sub-04/s .. t_dwi.nii.gz:  99%|████▉| 104M/105M [00:06<00:00, 9.92M Bytes/s]
#
# Get sub-04/s .. t_dwi.nii.gz:   0%|             | 0.00/105M [00:00<?, ? Bytes/s]
# Total:  95%|████████████████████████▋ | 2.06G/2.17G [02:20<00:07, 14.7M Bytes/s]
# Get sub-04/s .. _bold.nii.gz:   0%|            | 0.00/24.7M [00:00<?, ? Bytes/s]
# Get sub-04/s .. _bold.nii.gz:   7%|▏  | 1.81M/24.7M [00:00<00:02, 9.05M Bytes/s]
# Get sub-04/s .. _bold.nii.gz:  14%|▍  | 3.48M/24.7M [00:00<00:02, 8.58M Bytes/s]
# Get sub-04/s .. _bold.nii.gz:  18%|▌  | 4.35M/24.7M [00:00<00:02, 8.53M Bytes/s]
# Get sub-04/s .. _bold.nii.gz:  29%|▊  | 7.04M/24.7M [00:00<00:01, 10.6M Bytes/s]
# Get sub-04/s .. _bold.nii.gz:  47%|█▍ | 11.5M/24.7M [00:00<00:00, 15.2M Bytes/s]
# Get sub-04/s .. _bold.nii.gz:  56%|█▋ | 13.8M/24.7M [00:01<00:00, 16.9M Bytes/s]
# Get sub-04/s .. _bold.nii.gz:  63%|█▉ | 15.6M/24.7M [00:01<00:00, 17.1M Bytes/s]
# Get sub-04/s .. _bold.nii.gz:  71%|██▏| 17.5M/24.7M [00:01<00:00, 17.6M Bytes/s]
# Get sub-04/s .. _bold.nii.gz:  89%|██▋| 22.0M/24.7M [00:01<00:00, 19.6M Bytes/s]
# Get sub-04/s .. _bold.nii.gz:  98%|██▉| 24.1M/24.7M [00:01<00:00, 18.9M Bytes/s]
#
# Get sub-04/s .. _bold.nii.gz:   0%|            | 0.00/26.3M [00:00<?, ? Bytes/s]
# Get sub-04/s .. _bold.nii.gz:  15%|▍  | 4.00M/26.3M [00:00<00:01, 20.0M Bytes/s]
# Get sub-04/s .. _bold.nii.gz:  23%|▋  | 6.06M/26.3M [00:00<00:01, 19.7M Bytes/s]
# Get sub-04/s .. _bold.nii.gz:  39%|█▏ | 10.1M/26.3M [00:00<00:00, 20.4M Bytes/s]
# Get sub-04/s .. _bold.nii.gz:  46%|█▍ | 12.2M/26.3M [00:00<00:00, 20.4M Bytes/s]
# Get sub-04/s .. _bold.nii.gz:  62%|█▊ | 16.3M/26.3M [00:00<00:00, 20.4M Bytes/s]
# Get sub-04/s .. _bold.nii.gz:  70%|██ | 18.4M/26.3M [00:00<00:00, 20.6M Bytes/s]
# Get sub-04/s .. _bold.nii.gz:  78%|██▎| 20.5M/26.3M [00:01<00:00, 20.7M Bytes/s]
# Get sub-04/s .. _bold.nii.gz:  86%|██▌| 22.6M/26.3M [00:01<00:00, 20.7M Bytes/s]
# Get sub-04/s .. _bold.nii.gz:  94%|██▊| 24.7M/26.3M [00:01<00:00, 20.8M Bytes/s]
#
# Get sub-04/s .. _bold.nii.gz:   0%|            | 0.00/33.8M [00:00<?, ? Bytes/s]
# Get sub-04/s .. _bold.nii.gz:  12%|▎  | 3.95M/33.8M [00:00<00:01, 19.7M Bytes/s]
# Get sub-04/s .. _bold.nii.gz:  18%|▌  | 6.04M/33.8M [00:00<00:01, 20.2M Bytes/s]
# Get sub-04/s .. _bold.nii.gz:  24%|▋  | 8.15M/33.8M [00:00<00:01, 20.5M Bytes/s]
# Get sub-04/s .. _bold.nii.gz:  36%|█  | 12.2M/33.8M [00:00<00:01, 20.3M Bytes/s]
# Get sub-04/s .. _bold.nii.gz:  47%|█▍ | 16.0M/33.8M [00:00<00:00, 19.7M Bytes/s]
# Get sub-04/s .. _bold.nii.gz:  53%|█▌ | 18.0M/33.8M [00:00<00:00, 19.9M Bytes/s]
# Get sub-04/s .. _bold.nii.gz:  60%|█▊ | 20.2M/33.8M [00:01<00:00, 20.1M Bytes/s]
# Get sub-04/s .. _bold.nii.gz:  67%|█▉ | 22.5M/33.8M [00:01<00:00, 21.0M Bytes/s]
# Get sub-04/s .. _bold.nii.gz:  73%|██▏| 24.7M/33.8M [00:01<00:00, 21.1M Bytes/s]
# Get sub-04/s .. _bold.nii.gz:  85%|██▌| 28.9M/33.8M [00:01<00:00, 21.0M Bytes/s]
# Get sub-04/s .. _bold.nii.gz:  97%|██▉| 33.0M/33.8M [00:01<00:00, 20.8M Bytes/s]
#
# Get sub-04/s .. _bold.nii.gz:   0%|            | 0.00/12.9M [00:00<?, ? Bytes/s]
# Get sub-04/s .. _bold.nii.gz:  31%|▉  | 4.05M/12.9M [00:00<00:00, 20.2M Bytes/s]
# Get sub-04/s .. _bold.nii.gz:  48%|█▍ | 6.24M/12.9M [00:00<00:00, 20.9M Bytes/s]
# Get sub-04/s .. _bold.nii.gz:  78%|██▎| 10.1M/12.9M [00:00<00:00, 20.0M Bytes/s]
#
# Get sub-04/s .. _bold.nii.gz:   0%|            | 0.00/11.2M [00:00<?, ? Bytes/s]
# Get sub-04/s .. _bold.nii.gz:  19%|▌  | 2.15M/11.2M [00:00<00:00, 10.6M Bytes/s]
# Get sub-04/s .. _bold.nii.gz:  55%|█▋ | 6.10M/11.2M [00:00<00:00, 15.8M Bytes/s]
# Get sub-04/s .. _bold.nii.gz:  84%|██▌| 9.35M/11.2M [00:00<00:00, 16.1M Bytes/s]
# get(ok): sub-02/ses-retest/anat/sub-02_ses-retest_T1w.nii.gz (file) [from s3-PUBLIC...]
# get(ok): sub-02/ses-retest/dwi/sub-02_ses-retest_dwi.nii.gz (file) [from s3-PUBLIC...]
# get(ok): sub-02/ses-retest/func/sub-02_ses-retest_task-covertverbgeneration_bold.nii.gz (file) [from s3-PUBLIC...]
# get(ok): sub-02/ses-retest/func/sub-02_ses-retest_task-fingerfootlips_bold.nii.gz (file) [from s3-PUBLIC...]
# get(ok): sub-02/ses-retest/func/sub-02_ses-retest_task-linebisection_bold.nii.gz (file) [from s3-PUBLIC...]
# get(ok): sub-02/ses-retest/func/sub-02_ses-retest_task-overtverbgeneration_bold.nii.gz (file) [from s3-PUBLIC...]
# get(ok): sub-02/ses-retest/func/sub-02_ses-retest_task-overtwordrepetition_bold.nii.gz (file) [from s3-PUBLIC...]
# get(ok): sub-02/ses-test/anat/sub-02_ses-test_T1w.nii.gz (file) [from s3-PUBLIC...]
# get(ok): sub-02/ses-test/dwi/sub-02_ses-test_dwi.nii.gz (file) [from s3-PUBLIC...]
# get(ok): sub-02/ses-test/func/sub-02_ses-test_task-covertverbgeneration_bold.nii.gz (file) [from s3-PUBLIC...]
#   [60 similar messages have been suppressed; disable with datalad.ui.suppress-similar-results=off]
# get(ok): sub-02 (directory)
# get(ok): sub-01 (directory)
# get(ok): sub-05 (directory)
# get(ok): sub-03 (directory)
# get(ok): sub-04 (directory)
# action summary:
#   get (ok: 75)

# %%
# !tree -L 4 ds000114
# Out:
# ds000114
# ├── CHANGES
# ├── dataset_description.json
# ├── dwi.bval
# ├── dwi.bvec
# ├── participants.tsv
# ├── sub-01
# │   ├── ses-retest
# │   │   ├── anat
# │   │   │   └── sub-01_ses-retest_T1w.nii.gz -> ../../../.git/annex/objects/xm/25/MD5E-s8503839--3b3b49b2396b59ddd5a73b7f596f9e46.nii.gz/MD5E-s8503839--3b3b49b2396b59ddd5a73b7f596f9e46.nii.gz
# │   │   ├── dwi
# │   │   │   └── sub-01_ses-retest_dwi.nii.gz -> ../../../.git/annex/objects/0K/16/MD5E-s99899518--5ebac8e9e23180638dd68dde10b818be.nii.gz/MD5E-s99899518--5ebac8e9e23180638dd68dde10b818be.nii.gz
# │   │   └── func
# │   │       ├── sub-01_ses-retest_task-covertverbgeneration_bold.nii.gz -> ../../../.git/annex/objects/3q/Qf/MD5E-s22317848--b30f5b2f7a6039a3e384bcb40bec7e55.nii.gz/MD5E-s22317848--b30f5b2f7a6039a3e384bcb40bec7e55.nii.gz
# │   │       ├── sub-01_ses-retest_task-fingerfootlips_bold.nii.gz -> ../../../.git/annex/objects/26/6j/MD5E-s23793248--327e42d440f0557105bf7c05a3b9f1e8.nii.gz/MD5E-s23793248--327e42d440f0557105bf7c05a3b9f1e8.nii.gz
# │   │       ├── sub-01_ses-retest_task-linebisection_bold.nii.gz -> ../../../.git/annex/objects/qv/gf/MD5E-s30728838--58392e3ead9caeefe148a57c71dd5b44.nii.gz/MD5E-s30728838--58392e3ead9caeefe148a57c71dd5b44.nii.gz
# │   │       ├── sub-01_ses-retest_task-linebisection_events.tsv
# │   │       ├── sub-01_ses-retest_task-overtverbgeneration_bold.nii.gz -> ../../../.git/annex/objects/Fx/6K/MD5E-s11839146--5f62c005467de0dabc6ebcd09c3e7ec3.nii.gz/MD5E-s11839146--5f62c005467de0dabc6ebcd09c3e7ec3.nii.gz
# │   │       └── sub-01_ses-retest_task-overtwordrepetition_bold.nii.gz -> ../../../.git/annex/objects/x3/qW/MD5E-s10162063--a86a0f448872de33a901a6b639e975c9.nii.gz/MD5E-s10162063--a86a0f448872de33a901a6b639e975c9.nii.gz
# │   └── ses-test
# │       ├── anat
# │       │   └── sub-01_ses-test_T1w.nii.gz -> ../../../.git/annex/objects/QP/jm/MD5E-s8677710--d6820f6cb8fb965e864419c14f6a22d5.nii.gz/MD5E-s8677710--d6820f6cb8fb965e864419c14f6a22d5.nii.gz
# │       ├── dwi
# │       │   └── sub-01_ses-test_dwi.nii.gz -> ../../../.git/annex/objects/X2/kJ/MD5E-s104193417--454850ac9ed1c96c40b6b7946e51bf71.nii.gz/MD5E-s104193417--454850ac9ed1c96c40b6b7946e51bf71.nii.gz
# │       └── func
# │           ├── sub-01_ses-test_task-covertverbgeneration_bold.nii.gz -> ../../../.git/annex/objects/mx/zJ/MD5E-s22944165--71b1eda077a1003a177552f6c380323a.nii.gz/MD5E-s22944165--71b1eda077a1003a177552f6c380323a.nii.gz
# │           ├── sub-01_ses-test_task-fingerfootlips_bold.nii.gz -> ../../../.git/annex/objects/k6/4f/MD5E-s24454931--e9ab535d84a922b0c7ed52461244cf47.nii.gz/MD5E-s24454931--e9ab535d84a922b0c7ed52461244cf47.nii.gz
# │           ├── sub-01_ses-test_task-linebisection_bold.nii.gz -> ../../../.git/annex/objects/32/Qq/MD5E-s31617092--151bc230c3b577110883369b6fad0daa.nii.gz/MD5E-s31617092--151bc230c3b577110883369b6fad0daa.nii.gz
# │           ├── sub-01_ses-test_task-linebisection_events.tsv
# │           ├── sub-01_ses-test_task-overtverbgeneration_bold.nii.gz -> ../../../.git/annex/objects/p3/fZ/MD5E-s12048980--648c9094579aa5d047a5f6db468f9bc9.nii.gz/MD5E-s12048980--648c9094579aa5d047a5f6db468f9bc9.nii.gz
# │           └── sub-01_ses-test_task-overtwordrepetition_bold.nii.gz -> ../../../.git/annex/objects/56/GV/MD5E-s10362270--6a5c483d118db28ff8a62455def5501c.nii.gz/MD5E-s10362270--6a5c483d118db28ff8a62455def5501c.nii.gz
# ├── sub-02
# │   ├── ses-retest
# │   │   ├── anat
# │   │   │   └── sub-02_ses-retest_T1w.nii.gz -> ../../../.git/annex/objects/VV/x2/MD5E-s8901003--6ad41304cbd57904227d914c054dcdc3.nii.gz/MD5E-s8901003--6ad41304cbd57904227d914c054dcdc3.nii.gz
# │   │   ├── dwi
# │   │   │   └── sub-02_ses-retest_dwi.nii.gz -> ../../../.git/annex/objects/ZZ/4X/MD5E-s101314358--9be934908a88073bc070e524651ee665.nii.gz/MD5E-s101314358--9be934908a88073bc070e524651ee665.nii.gz
# │   │   └── func
# │   │       ├── sub-02_ses-retest_task-covertverbgeneration_bold.nii.gz -> ../../../.git/annex/objects/vk/gK/MD5E-s22730907--26df7900a64e1d9f90e17ad0fa53145d.nii.gz/MD5E-s22730907--26df7900a64e1d9f90e17ad0fa53145d.nii.gz
# │   │       ├── sub-02_ses-retest_task-fingerfootlips_bold.nii.gz -> ../../../.git/annex/objects/Jg/vq/MD5E-s24364271--593256c66ce88ed8aaef140a4b37c6ec.nii.gz/MD5E-s24364271--593256c66ce88ed8aaef140a4b37c6ec.nii.gz
# │   │       ├── sub-02_ses-retest_task-linebisection_bold.nii.gz -> ../../../.git/annex/objects/pZ/GJ/MD5E-s31238024--929a3999fa92002e571bec60f7343b65.nii.gz/MD5E-s31238024--929a3999fa92002e571bec60f7343b65.nii.gz
# │   │       ├── sub-02_ses-retest_task-linebisection_events.tsv
# │   │       ├── sub-02_ses-retest_task-overtverbgeneration_bold.nii.gz -> ../../../.git/annex/objects/35/2V/MD5E-s12039294--070d0299974f916bdee0791985381593.nii.gz/MD5E-s12039294--070d0299974f916bdee0791985381593.nii.gz
# │   │       └── sub-02_ses-retest_task-overtwordrepetition_bold.nii.gz -> ../../../.git/annex/objects/Z4/0G/MD5E-s10369674--71d655f61e4ce98ae7761ce76e3c30f9.nii.gz/MD5E-s10369674--71d655f61e4ce98ae7761ce76e3c30f9.nii.gz
# │   └── ses-test
# │       ├── anat
# │       │   └── sub-02_ses-test_T1w.nii.gz -> ../../../.git/annex/objects/qq/gm/MD5E-s10025785--0e790e210a275d76e3f2f4d895df6358.nii.gz/MD5E-s10025785--0e790e210a275d76e3f2f4d895df6358.nii.gz
# │       ├── dwi
# │       │   └── sub-02_ses-test_dwi.nii.gz -> ../../../.git/annex/objects/8x/vp/MD5E-s104222416--86575d07809e9c717079592a12c69344.nii.gz/MD5E-s104222416--86575d07809e9c717079592a12c69344.nii.gz
# │       └── func
# │           ├── sub-02_ses-test_task-covertverbgeneration_bold.nii.gz -> ../../../.git/annex/objects/F6/6J/MD5E-s23349944--2a2b8bc1f3d90e84d879bdd4638103c8.nii.gz/MD5E-s23349944--2a2b8bc1f3d90e84d879bdd4638103c8.nii.gz
# │           ├── sub-02_ses-test_task-fingerfootlips_bold.nii.gz -> ../../../.git/annex/objects/pG/k1/MD5E-s24882575--75c39bee9e25e02c629dfcce1b378589.nii.gz/MD5E-s24882575--75c39bee9e25e02c629dfcce1b378589.nii.gz
# │           ├── sub-02_ses-test_task-linebisection_bold.nii.gz -> ../../../.git/annex/objects/WM/m9/MD5E-s32248732--4cd877de7b4c66e073610dffb67dfbcc.nii.gz/MD5E-s32248732--4cd877de7b4c66e073610dffb67dfbcc.nii.gz
# │           ├── sub-02_ses-test_task-linebisection_events.tsv
# │           ├── sub-02_ses-test_task-overtverbgeneration_bold.nii.gz -> ../../../.git/annex/objects/Jz/zM/MD5E-s12348374--67f259c7e0bbb0fe39e747be5f905a4b.nii.gz/MD5E-s12348374--67f259c7e0bbb0fe39e747be5f905a4b.nii.gz
# │           └── sub-02_ses-test_task-overtwordrepetition_bold.nii.gz -> ../../../.git/annex/objects/6g/Zw/MD5E-s10496422--bae24132d514bb028ca8a3d749363bd9.nii.gz/MD5E-s10496422--bae24132d514bb028ca8a3d749363bd9.nii.gz
# ├── sub-03
# │   ├── ses-retest
# │   │   ├── anat
# │   │   │   └── sub-03_ses-retest_T1w.nii.gz -> ../../../.git/annex/objects/64/vk/MD5E-s8125470--75575589e60ce58d95b4d72d3b4bf222.nii.gz/MD5E-s8125470--75575589e60ce58d95b4d72d3b4bf222.nii.gz
# │   │   ├── dwi
# │   │   │   └── sub-03_ses-retest_dwi.nii.gz -> ../../../.git/annex/objects/Pf/07/MD5E-s101660442--50491e142880d5f32b6c33cde372fb05.nii.gz/MD5E-s101660442--50491e142880d5f32b6c33cde372fb05.nii.gz
# │   │   └── func
# │   │       ├── sub-03_ses-retest_task-covertverbgeneration_bold.nii.gz -> ../../../.git/annex/objects/z1/0p/MD5E-s22709259--a01b5167228be96f007e84bab43e8b60.nii.gz/MD5E-s22709259--a01b5167228be96f007e84bab43e8b60.nii.gz
# │   │       ├── sub-03_ses-retest_task-fingerfootlips_bold.nii.gz -> ../../../.git/annex/objects/WG/k5/MD5E-s24175561--769ba7da6cac3318c47bc9215a77359b.nii.gz/MD5E-s24175561--769ba7da6cac3318c47bc9215a77359b.nii.gz
# │   │       ├── sub-03_ses-retest_task-linebisection_bold.nii.gz -> ../../../.git/annex/objects/Qf/QX/MD5E-s31217356--89a8e84fbe0b5f019ce69d4ad643863c.nii.gz/MD5E-s31217356--89a8e84fbe0b5f019ce69d4ad643863c.nii.gz
# │   │       ├── sub-03_ses-retest_task-linebisection_events.tsv
# │   │       ├── sub-03_ses-retest_task-overtverbgeneration_bold.nii.gz -> ../../../.git/annex/objects/Xx/q2/MD5E-s11992800--894dac07de9c8cddf6ea7e42f39f5c80.nii.gz/MD5E-s11992800--894dac07de9c8cddf6ea7e42f39f5c80.nii.gz
# │   │       └── sub-03_ses-retest_task-overtwordrepetition_bold.nii.gz -> ../../../.git/annex/objects/7F/8p/MD5E-s10359493--9b3e5cc9933645901049c64c600ec6ca.nii.gz/MD5E-s10359493--9b3e5cc9933645901049c64c600ec6ca.nii.gz
# │   └── ses-test
# │       ├── anat
# │       │   └── sub-03_ses-test_T1w.nii.gz -> ../../../.git/annex/objects/P9/kj/MD5E-s7970968--75bb38265ea96864bfa0b012ba21b0b0.nii.gz/MD5E-s7970968--75bb38265ea96864bfa0b012ba21b0b0.nii.gz
# │       ├── dwi
# │       │   └── sub-03_ses-test_dwi.nii.gz -> ../../../.git/annex/objects/F3/Pf/MD5E-s106544064--badea2659bd4440ff4c20e2f149034cc.nii.gz/MD5E-s106544064--badea2659bd4440ff4c20e2f149034cc.nii.gz
# │       └── func
# │           ├── sub-03_ses-test_task-covertverbgeneration_bold.nii.gz -> ../../../.git/annex/objects/J6/f0/MD5E-s23145742--a792c0592cb77a161eb5d000a618c17c.nii.gz/MD5E-s23145742--a792c0592cb77a161eb5d000a618c17c.nii.gz
# │           ├── sub-03_ses-test_task-fingerfootlips_bold.nii.gz -> ../../../.git/annex/objects/gp/QM/MD5E-s24520513--0fd08e07bbee37ac9efe14c7b265299a.nii.gz/MD5E-s24520513--0fd08e07bbee37ac9efe14c7b265299a.nii.gz
# │           ├── sub-03_ses-test_task-linebisection_bold.nii.gz -> ../../../.git/annex/objects/mP/mg/MD5E-s31785134--76856b9d6c90730144196aa48e4d9a9f.nii.gz/MD5E-s31785134--76856b9d6c90730144196aa48e4d9a9f.nii.gz
# │           ├── sub-03_ses-test_task-linebisection_events.tsv
# │           ├── sub-03_ses-test_task-overtverbgeneration_bold.nii.gz -> ../../../.git/annex/objects/w3/XQ/MD5E-s12159084--67f84031d332467dae91107e53f0d89e.nii.gz/MD5E-s12159084--67f84031d332467dae91107e53f0d89e.nii.gz
# │           └── sub-03_ses-test_task-overtwordrepetition_bold.nii.gz -> ../../../.git/annex/objects/Qk/kK/MD5E-s10552089--e00b7544d9c44dddcd966e2c1dcd468f.nii.gz/MD5E-s10552089--e00b7544d9c44dddcd966e2c1dcd468f.nii.gz
# ├── sub-04
# │   ├── ses-retest
# │   │   ├── anat
# │   │   │   └── sub-04_ses-retest_T1w.nii.gz -> ../../../.git/annex/objects/z9/V6/MD5E-s10125819--92fcdbdd50bb334651e474417237a7f2.nii.gz/MD5E-s10125819--92fcdbdd50bb334651e474417237a7f2.nii.gz
# │   │   ├── dwi
# │   │   │   └── sub-04_ses-retest_dwi.nii.gz -> ../../../.git/annex/objects/0Q/z6/MD5E-s102315940--827455ba66acecb6a2c8b9222bcd9fa1.nii.gz/MD5E-s102315940--827455ba66acecb6a2c8b9222bcd9fa1.nii.gz
# │   │   └── func
# │   │       ├── sub-04_ses-retest_task-covertverbgeneration_bold.nii.gz -> ../../../.git/annex/objects/6G/PV/MD5E-s24644977--c2411e3bad71cddeb2c083f999d22f93.nii.gz/MD5E-s24644977--c2411e3bad71cddeb2c083f999d22f93.nii.gz
# │   │       ├── sub-04_ses-retest_task-fingerfootlips_bold.nii.gz -> ../../../.git/annex/objects/Jf/m1/MD5E-s26197435--1ec999d21c0039897b67f38f5870d70c.nii.gz/MD5E-s26197435--1ec999d21c0039897b67f38f5870d70c.nii.gz
# │   │       ├── sub-04_ses-retest_task-linebisection_bold.nii.gz -> ../../../.git/annex/objects/J2/v9/MD5E-s33748727--044de5969956d86b7cdee0eb36e26c9e.nii.gz/MD5E-s33748727--044de5969956d86b7cdee0eb36e26c9e.nii.gz
# │   │       ├── sub-04_ses-retest_task-linebisection_events.tsv
# │   │       ├── sub-04_ses-retest_task-overtverbgeneration_bold.nii.gz -> ../../../.git/annex/objects/Kf/5K/MD5E-s12862957--a356882c1f18391f2f5215bda39f817f.nii.gz/MD5E-s12862957--a356882c1f18391f2f5215bda39f817f.nii.gz
# │   │       └── sub-04_ses-retest_task-overtwordrepetition_bold.nii.gz -> ../../../.git/annex/objects/70/k3/MD5E-s11172082--dcd559966a66e0645cb98a9b13c67a6c.nii.gz/MD5E-s11172082--dcd559966a66e0645cb98a9b13c67a6c.nii.gz
# │   └── ses-test
# │       ├── anat
# │       │   └── sub-04_ses-test_T1w.nii.gz -> ../../../.git/annex/objects/mg/5z/MD5E-s9717713--7764ef9c3fb344f69f1c2eb34cd56046.nii.gz/MD5E-s9717713--7764ef9c3fb344f69f1c2eb34cd56046.nii.gz
# │       ├── dwi
# │       │   └── sub-04_ses-test_dwi.nii.gz -> ../../../.git/annex/objects/W0/Gk/MD5E-s104883316--ec0aec8977aa5a5c0901cd9d2e25347c.nii.gz/MD5E-s104883316--ec0aec8977aa5a5c0901cd9d2e25347c.nii.gz
# │       └── func
# │           ├── sub-04_ses-test_task-covertverbgeneration_bold.nii.gz -> ../../../.git/annex/objects/GX/QK/MD5E-s24677139--d835385cb69d9907d6b0cb7311a91ff3.nii.gz/MD5E-s24677139--d835385cb69d9907d6b0cb7311a91ff3.nii.gz
# │           ├── sub-04_ses-test_task-fingerfootlips_bold.nii.gz -> ../../../.git/annex/objects/Qv/qX/MD5E-s26270785--61f837b1ef1f667975ab25b820844d93.nii.gz/MD5E-s26270785--61f837b1ef1f667975ab25b820844d93.nii.gz
# │           ├── sub-04_ses-test_task-linebisection_bold.nii.gz -> ../../../.git/annex/objects/gk/3p/MD5E-s33823763--377e091ada8819942070a374b71ea986.nii.gz/MD5E-s33823763--377e091ada8819942070a374b71ea986.nii.gz
# │           ├── sub-04_ses-test_task-linebisection_events.tsv
# │           ├── sub-04_ses-test_task-overtverbgeneration_bold.nii.gz -> ../../../.git/annex/objects/0Q/jG/MD5E-s12907201--46e3c39a8f7ec6c2f5b1ab157efa10d1.nii.gz/MD5E-s12907201--46e3c39a8f7ec6c2f5b1ab157efa10d1.nii.gz
# │           └── sub-04_ses-test_task-overtwordrepetition_bold.nii.gz -> ../../../.git/annex/objects/X5/FJ/MD5E-s11171792--bc9ba9ef24fcf364f3057401c17b1c49.nii.gz/MD5E-s11171792--bc9ba9ef24fcf364f3057401c17b1c49.nii.gz
# ├── sub-05
# │   ├── ses-retest
# │   │   ├── anat
# │   │   │   └── sub-05_ses-retest_T1w.nii.gz -> ../../../.git/annex/objects/JK/PV/MD5E-s9511479--cec6ad961369ea1b21521d33040406d1.nii.gz/MD5E-s9511479--cec6ad961369ea1b21521d33040406d1.nii.gz
# │   │   ├── dwi
# │   │   │   └── sub-05_ses-retest_dwi.nii.gz -> ../../../.git/annex/objects/Mx/KM/MD5E-s104024235--7a107b0b7d70f0e0a60e5fccbda23f41.nii.gz/MD5E-s104024235--7a107b0b7d70f0e0a60e5fccbda23f41.nii.gz
# │   │   └── func
# │   │       ├── sub-05_ses-retest_task-covertverbgeneration_bold.nii.gz -> ../../../.git/annex/objects/x3/7x/MD5E-s24240966--89dc3e4888f5788e390be04cc91565ef.nii.gz/MD5E-s24240966--89dc3e4888f5788e390be04cc91565ef.nii.gz
# │   │       ├── sub-05_ses-retest_task-fingerfootlips_bold.nii.gz -> ../../../.git/annex/objects/V4/fV/MD5E-s25998505--071b1bd89a8d245b7a7a23323b434706.nii.gz/MD5E-s25998505--071b1bd89a8d245b7a7a23323b434706.nii.gz
# │   │       ├── sub-05_ses-retest_task-linebisection_bold.nii.gz -> ../../../.git/annex/objects/3v/1w/MD5E-s33598359--952f5c8625b962a9f5ccb3d2bb58d1aa.nii.gz/MD5E-s33598359--952f5c8625b962a9f5ccb3d2bb58d1aa.nii.gz
# │   │       ├── sub-05_ses-retest_task-linebisection_events.tsv
# │   │       ├── sub-05_ses-retest_task-overtverbgeneration_bold.nii.gz -> ../../../.git/annex/objects/w0/75/MD5E-s12942731--e26171327d6bbdd4f392e1e327f92850.nii.gz/MD5E-s12942731--e26171327d6bbdd4f392e1e327f92850.nii.gz
# │   │       └── sub-05_ses-retest_task-overtwordrepetition_bold.nii.gz -> ../../../.git/annex/objects/2V/K8/MD5E-s11109819--e0875ced4e44d9a144316893937a063b.nii.gz/MD5E-s11109819--e0875ced4e44d9a144316893937a063b.nii.gz
# │   └── ses-test
# │       ├── anat
# │       │   └── sub-05_ses-test_T1w.nii.gz -> ../../../.git/annex/objects/f1/XP/MD5E-s9942928--e32c1d5fb1d6db6449b19be10b5efc67.nii.gz/MD5E-s9942928--e32c1d5fb1d6db6449b19be10b5efc67.nii.gz
# │       ├── dwi
# │       │   └── sub-05_ses-test_dwi.nii.gz -> ../../../.git/annex/objects/q3/gK/MD5E-s108049676--0d107c0acf9bed884baedfb7bc6a76e7.nii.gz/MD5E-s108049676--0d107c0acf9bed884baedfb7bc6a76e7.nii.gz
# │       └── func
# │           ├── sub-05_ses-test_task-covertverbgeneration_bold.nii.gz -> ../../../.git/annex/objects/0z/1V/MD5E-s24924488--f11c9aec356aa58e53e7a154222f4e74.nii.gz/MD5E-s24924488--f11c9aec356aa58e53e7a154222f4e74.nii.gz
# │           ├── sub-05_ses-test_task-fingerfootlips_bold.nii.gz -> ../../../.git/annex/objects/GK/P9/MD5E-s26693258--a904caebfaa372a21eb37231bae55299.nii.gz/MD5E-s26693258--a904caebfaa372a21eb37231bae55299.nii.gz
# │           ├── sub-05_ses-test_task-linebisection_bold.nii.gz -> ../../../.git/annex/objects/jW/X3/MD5E-s34416273--467b8d34b985d8caa2ac26e93506b775.nii.gz/MD5E-s34416273--467b8d34b985d8caa2ac26e93506b775.nii.gz
# │           ├── sub-05_ses-test_task-linebisection_events.tsv
# │           ├── sub-05_ses-test_task-overtverbgeneration_bold.nii.gz -> ../../../.git/annex/objects/fZ/Qx/MD5E-s13124683--f6b7dbf08272097300cf977ddc06a3a3.nii.gz/MD5E-s13124683--f6b7dbf08272097300cf977ddc06a3a3.nii.gz
# │           └── sub-05_ses-test_task-overtwordrepetition_bold.nii.gz -> ../../../.git/annex/objects/wP/ZP/MD5E-s11526323--f99a4f1f281cc1213c556b1f446724e5.nii.gz/MD5E-s11526323--f99a4f1f281cc1213c556b1f446724e5.nii.gz
# ├── sub-06
# │   ├── ses-retest
# │   │   ├── anat
# │   │   │   └── sub-06_ses-retest_T1w.nii.gz -> ../../../.git/annex/objects/9W/pF/MD5E-s9712028--b4fbccf8add0667a4cba4306d2609bf6.nii.gz/MD5E-s9712028--b4fbccf8add0667a4cba4306d2609bf6.nii.gz
# │   │   ├── dwi
# │   │   │   └── sub-06_ses-retest_dwi.nii.gz -> ../../../.git/annex/objects/82/0m/MD5E-s102946238--20e290d95ed62fe68f5c73c3e057aa68.nii.gz/MD5E-s102946238--20e290d95ed62fe68f5c73c3e057aa68.nii.gz
# │   │   └── func
# │   │       ├── sub-06_ses-retest_task-covertverbgeneration_bold.nii.gz -> ../../../.git/annex/objects/KQ/41/MD5E-s24361814--23edea0b5a1c7b770ae89a700099482a.nii.gz/MD5E-s24361814--23edea0b5a1c7b770ae89a700099482a.nii.gz
# │   │       ├── sub-06_ses-retest_task-fingerfootlips_bold.nii.gz -> ../../../.git/annex/objects/MW/2q/MD5E-s26020756--5525a120e543de5a7c561eb0ac058c50.nii.gz/MD5E-s26020756--5525a120e543de5a7c561eb0ac058c50.nii.gz
# │   │       ├── sub-06_ses-retest_task-linebisection_bold.nii.gz -> ../../../.git/annex/objects/kz/g4/MD5E-s33607078--55b31ff735c4a5d571e49ca0fa44ef3b.nii.gz/MD5E-s33607078--55b31ff735c4a5d571e49ca0fa44ef3b.nii.gz
# │   │       ├── sub-06_ses-retest_task-linebisection_events.tsv
# │   │       ├── sub-06_ses-retest_task-overtverbgeneration_bold.nii.gz -> ../../../.git/annex/objects/qf/92/MD5E-s12884913--85e85fa3810ffbc274163169994516ce.nii.gz/MD5E-s12884913--85e85fa3810ffbc274163169994516ce.nii.gz
# │   │       └── sub-06_ses-retest_task-overtwordrepetition_bold.nii.gz -> ../../../.git/annex/objects/zx/Mx/MD5E-s11071105--d4dc6401799624f330849cb2a26ecce0.nii.gz/MD5E-s11071105--d4dc6401799624f330849cb2a26ecce0.nii.gz
# │   └── ses-test
# │       ├── anat
# │       │   └── sub-06_ses-test_T1w.nii.gz -> ../../../.git/annex/objects/gm/9z/MD5E-s10429286--0dcb4734fa4f0bccc2f7b953e630e24d.nii.gz/MD5E-s10429286--0dcb4734fa4f0bccc2f7b953e630e24d.nii.gz
# │       ├── dwi
# │       │   └── sub-06_ses-test_dwi.nii.gz -> ../../../.git/annex/objects/q4/Jf/MD5E-s111500846--b91fca5d1ca3b959becfc5da8923aab1.nii.gz/MD5E-s111500846--b91fca5d1ca3b959becfc5da8923aab1.nii.gz
# │       └── func
# │           ├── sub-06_ses-test_task-covertverbgeneration_bold.nii.gz -> ../../../.git/annex/objects/K1/PM/MD5E-s25380586--d07bdf55b059b9532106bdf96c3d5be6.nii.gz/MD5E-s25380586--d07bdf55b059b9532106bdf96c3d5be6.nii.gz
# │           ├── sub-06_ses-test_task-fingerfootlips_bold.nii.gz -> ../../../.git/annex/objects/V9/52/MD5E-s26868014--5c133cbc6d656f72433b1c5da1ea66e7.nii.gz/MD5E-s26868014--5c133cbc6d656f72433b1c5da1ea66e7.nii.gz
# │           ├── sub-06_ses-test_task-linebisection_bold.nii.gz -> ../../../.git/annex/objects/x0/Z9/MD5E-s34846203--cd71c6d597806515b0f8b956637c33a1.nii.gz/MD5E-s34846203--cd71c6d597806515b0f8b956637c33a1.nii.gz
# │           ├── sub-06_ses-test_task-linebisection_events.tsv
# │           ├── sub-06_ses-test_task-overtverbgeneration_bold.nii.gz -> ../../../.git/annex/objects/KV/31/MD5E-s13292168--c6397d91154050fe59a42da6316b0d4b.nii.gz/MD5E-s13292168--c6397d91154050fe59a42da6316b0d4b.nii.gz
# │           └── sub-06_ses-test_task-overtwordrepetition_bold.nii.gz -> ../../../.git/annex/objects/6K/wQ/MD5E-s11225007--3a39708bd39fa2e4fadccbbf3056bb4e.nii.gz/MD5E-s11225007--3a39708bd39fa2e4fadccbbf3056bb4e.nii.gz
# ├── sub-07
# │   ├── ses-retest
# │   │   ├── anat
# │   │   │   └── sub-07_ses-retest_T1w.nii.gz -> ../../../.git/annex/objects/wz/fx/MD5E-s8725991--d2be2d444bca2a33e53521f5aa9fafaa.nii.gz/MD5E-s8725991--d2be2d444bca2a33e53521f5aa9fafaa.nii.gz
# │   │   ├── dwi
# │   │   │   └── sub-07_ses-retest_dwi.nii.gz -> ../../../.git/annex/objects/wP/wJ/MD5E-s101870616--440ae52ddacae1affe2e1f59ac795dd3.nii.gz/MD5E-s101870616--440ae52ddacae1affe2e1f59ac795dd3.nii.gz
# │   │   └── func
# │   │       ├── sub-07_ses-retest_task-covertverbgeneration_bold.nii.gz -> ../../../.git/annex/objects/Kk/4J/MD5E-s22958973--c4ed743b362967e6fa2da91f07fb5e4b.nii.gz/MD5E-s22958973--c4ed743b362967e6fa2da91f07fb5e4b.nii.gz
# │   │       ├── sub-07_ses-retest_task-fingerfootlips_bold.nii.gz -> ../../../.git/annex/objects/V3/KV/MD5E-s24493127--2a5924ea580a6156a268fd785ed5a920.nii.gz/MD5E-s24493127--2a5924ea580a6156a268fd785ed5a920.nii.gz
# │   │       ├── sub-07_ses-retest_task-linebisection_bold.nii.gz -> ../../../.git/annex/objects/Fq/0m/MD5E-s31692006--899332b77616cec163c34a33133db1ad.nii.gz/MD5E-s31692006--899332b77616cec163c34a33133db1ad.nii.gz
# │   │       ├── sub-07_ses-retest_task-linebisection_events.tsv
# │   │       ├── sub-07_ses-retest_task-overtverbgeneration_bold.nii.gz -> ../../../.git/annex/objects/qf/Fx/MD5E-s12040345--b22b478fbe5db9a29a44a6181a9ca742.nii.gz/MD5E-s12040345--b22b478fbe5db9a29a44a6181a9ca742.nii.gz
# │   │       └── sub-07_ses-retest_task-overtwordrepetition_bold.nii.gz -> ../../../.git/annex/objects/qZ/36/MD5E-s10217500--ff1be72ed50f666ffeca2aec2b33c9ed.nii.gz/MD5E-s10217500--ff1be72ed50f666ffeca2aec2b33c9ed.nii.gz
# │   └── ses-test
# │       ├── anat
# │       │   └── sub-07_ses-test_T1w.nii.gz -> ../../../.git/annex/objects/2Q/jJ/MD5E-s8580756--2f14ce817190386a6b4cbf77f89492e1.nii.gz/MD5E-s8580756--2f14ce817190386a6b4cbf77f89492e1.nii.gz
# │       ├── dwi
# │       │   └── sub-07_ses-test_dwi.nii.gz -> ../../../.git/annex/objects/zG/84/MD5E-s103326300--7fdd20ad61b709937d1cc5bb2e0798c6.nii.gz/MD5E-s103326300--7fdd20ad61b709937d1cc5bb2e0798c6.nii.gz
# │       └── func
# │           ├── sub-07_ses-test_task-covertverbgeneration_bold.nii.gz -> ../../../.git/annex/objects/V3/g1/MD5E-s23258547--3eac6de7ef215928b8e3124f19ea8a8c.nii.gz/MD5E-s23258547--3eac6de7ef215928b8e3124f19ea8a8c.nii.gz
# │           ├── sub-07_ses-test_task-fingerfootlips_bold.nii.gz -> ../../../.git/annex/objects/Xf/kK/MD5E-s24751878--661682e4f762d7c99dbf049fcc658c87.nii.gz/MD5E-s24751878--661682e4f762d7c99dbf049fcc658c87.nii.gz
# │           ├── sub-07_ses-test_task-linebisection_bold.nii.gz -> ../../../.git/annex/objects/pG/qJ/MD5E-s32129273--5d4591dadeabaed078c7519da44178fb.nii.gz/MD5E-s32129273--5d4591dadeabaed078c7519da44178fb.nii.gz
# │           ├── sub-07_ses-test_task-linebisection_events.tsv
# │           ├── sub-07_ses-test_task-overtverbgeneration_bold.nii.gz -> ../../../.git/annex/objects/x4/J8/MD5E-s12271868--80db70ef7a5e5c78f7a5cdd16a636f11.nii.gz/MD5E-s12271868--80db70ef7a5e5c78f7a5cdd16a636f11.nii.gz
# │           └── sub-07_ses-test_task-overtwordrepetition_bold.nii.gz -> ../../../.git/annex/objects/zZ/61/MD5E-s10521017--969638eda30b31ad90b2403d5cc10b20.nii.gz/MD5E-s10521017--969638eda30b31ad90b2403d5cc10b20.nii.gz
# ├── sub-08
# │   ├── ses-retest
# │   │   ├── anat
# │   │   │   └── sub-08_ses-retest_T1w.nii.gz -> ../../../.git/annex/objects/G3/j0/MD5E-s9815716--3ccef5772c262fd48ee053f97a3381ce.nii.gz/MD5E-s9815716--3ccef5772c262fd48ee053f97a3381ce.nii.gz
# │   │   ├── dwi
# │   │   │   └── sub-08_ses-retest_dwi.nii.gz -> ../../../.git/annex/objects/QJ/gw/MD5E-s104814386--e6cab512bec21cf56a56833041fb513c.nii.gz/MD5E-s104814386--e6cab512bec21cf56a56833041fb513c.nii.gz
# │   │   └── func
# │   │       ├── sub-08_ses-retest_task-covertverbgeneration_bold.nii.gz -> ../../../.git/annex/objects/QP/w0/MD5E-s24230763--51bc4ea41cba2f3a9d15be16f6c34d02.nii.gz/MD5E-s24230763--51bc4ea41cba2f3a9d15be16f6c34d02.nii.gz
# │   │       ├── sub-08_ses-retest_task-fingerfootlips_bold.nii.gz -> ../../../.git/annex/objects/48/X1/MD5E-s25800747--f446847b95b4e32814564f9197271ed9.nii.gz/MD5E-s25800747--f446847b95b4e32814564f9197271ed9.nii.gz
# │   │       ├── sub-08_ses-retest_task-linebisection_bold.nii.gz -> ../../../.git/annex/objects/fP/63/MD5E-s33353778--6a1da1d5367e05e8a62702feeae571d9.nii.gz/MD5E-s33353778--6a1da1d5367e05e8a62702feeae571d9.nii.gz
# │   │       ├── sub-08_ses-retest_task-linebisection_events.tsv
# │   │       ├── sub-08_ses-retest_task-overtverbgeneration_bold.nii.gz -> ../../../.git/annex/objects/75/86/MD5E-s12754775--52ec0425828a22ec5770d853aca3a446.nii.gz/MD5E-s12754775--52ec0425828a22ec5770d853aca3a446.nii.gz
# │   │       └── sub-08_ses-retest_task-overtwordrepetition_bold.nii.gz -> ../../../.git/annex/objects/gW/KF/MD5E-s10970580--4060fc6ee9f4383aed5c49e4cded633a.nii.gz/MD5E-s10970580--4060fc6ee9f4383aed5c49e4cded633a.nii.gz
# │   └── ses-test
# │       ├── anat
# │       │   └── sub-08_ses-test_T1w.nii.gz -> ../../../.git/annex/objects/85/WP/MD5E-s9325328--35d0ce9fd75157df786d11c84b3c2178.nii.gz/MD5E-s9325328--35d0ce9fd75157df786d11c84b3c2178.nii.gz
# │       ├── dwi
# │       │   └── sub-08_ses-test_dwi.nii.gz -> ../../../.git/annex/objects/MM/v4/MD5E-s102691986--702eadb2a87f9cc17b8c62c64b27a8fb.nii.gz/MD5E-s102691986--702eadb2a87f9cc17b8c62c64b27a8fb.nii.gz
# │       └── func
# │           ├── sub-08_ses-test_task-covertverbgeneration_bold.nii.gz -> ../../../.git/annex/objects/4g/25/MD5E-s24002538--085dc82910b78be26a215d4c51194aea.nii.gz/MD5E-s24002538--085dc82910b78be26a215d4c51194aea.nii.gz
# │           ├── sub-08_ses-test_task-fingerfootlips_bold.nii.gz -> ../../../.git/annex/objects/4g/pV/MD5E-s25655723--fddb912934403f6cd56dd32277e4be69.nii.gz/MD5E-s25655723--fddb912934403f6cd56dd32277e4be69.nii.gz
# │           ├── sub-08_ses-test_task-linebisection_bold.nii.gz -> ../../../.git/annex/objects/v0/Vf/MD5E-s33201889--0647f2251ac5f125b4b84ca5a93e37ca.nii.gz/MD5E-s33201889--0647f2251ac5f125b4b84ca5a93e37ca.nii.gz
# │           ├── sub-08_ses-test_task-linebisection_events.tsv
# │           ├── sub-08_ses-test_task-overtverbgeneration_bold.nii.gz -> ../../../.git/annex/objects/Kf/11/MD5E-s12622070--c140fdd9e3e5747b9c9a8ff8dcc949cf.nii.gz/MD5E-s12622070--c140fdd9e3e5747b9c9a8ff8dcc949cf.nii.gz
# │           └── sub-08_ses-test_task-overtwordrepetition_bold.nii.gz -> ../../../.git/annex/objects/8g/2p/MD5E-s10907328--1188c30e16c68cd270d02aa8d554f24d.nii.gz/MD5E-s10907328--1188c30e16c68cd270d02aa8d554f24d.nii.gz
# ├── sub-09
# │   ├── ses-retest
# │   │   ├── anat
# │   │   │   └── sub-09_ses-retest_T1w.nii.gz -> ../../../.git/annex/objects/XM/9P/MD5E-s9038046--abcb37f89145be848b1b6c19c69b4e66.nii.gz/MD5E-s9038046--abcb37f89145be848b1b6c19c69b4e66.nii.gz
# │   │   ├── dwi
# │   │   │   └── sub-09_ses-retest_dwi.nii.gz -> ../../../.git/annex/objects/g5/GQ/MD5E-s104913036--9af1945a4e26239a938536e6eb962630.nii.gz/MD5E-s104913036--9af1945a4e26239a938536e6eb962630.nii.gz
# │   │   └── func
# │   │       ├── sub-09_ses-retest_task-covertverbgeneration_bold.nii.gz -> ../../../.git/annex/objects/qp/56/MD5E-s23883001--7eb7d4a5b01596f680d0d748473f1f38.nii.gz/MD5E-s23883001--7eb7d4a5b01596f680d0d748473f1f38.nii.gz
# │   │       ├── sub-09_ses-retest_task-fingerfootlips_bold.nii.gz -> ../../../.git/annex/objects/KM/3m/MD5E-s25333347--98c608533e6f0f0148d1b4223578a7e0.nii.gz/MD5E-s25333347--98c608533e6f0f0148d1b4223578a7e0.nii.gz
# │   │       ├── sub-09_ses-retest_task-linebisection_bold.nii.gz -> ../../../.git/annex/objects/jG/KZ/MD5E-s32759028--0e0b0badca8ad941baea5212d0bbd4c8.nii.gz/MD5E-s32759028--0e0b0badca8ad941baea5212d0bbd4c8.nii.gz
# │   │       ├── sub-09_ses-retest_task-linebisection_events.tsv
# │   │       ├── sub-09_ses-retest_task-overtverbgeneration_bold.nii.gz -> ../../../.git/annex/objects/Wk/x1/MD5E-s12607832--fa71f8dbe19dbb58fc8e56fd4c0d74a9.nii.gz/MD5E-s12607832--fa71f8dbe19dbb58fc8e56fd4c0d74a9.nii.gz
# │   │       └── sub-09_ses-retest_task-overtwordrepetition_bold.nii.gz -> ../../../.git/annex/objects/1F/Qk/MD5E-s10992778--c0e5683ec6bed25d407e896cef3a4cc3.nii.gz/MD5E-s10992778--c0e5683ec6bed25d407e896cef3a4cc3.nii.gz
# │   └── ses-test
# │       ├── anat
# │       │   └── sub-09_ses-test_T1w.nii.gz -> ../../../.git/annex/objects/0w/6v/MD5E-s9093983--6307afbbcebf1d2bfe945a1e963d3a9d.nii.gz/MD5E-s9093983--6307afbbcebf1d2bfe945a1e963d3a9d.nii.gz
# │       ├── dwi
# │       │   └── sub-09_ses-test_dwi.nii.gz -> ../../../.git/annex/objects/F8/6K/MD5E-s106806289--ed3b50d7d009964e8fbfb2d0250fc67e.nii.gz/MD5E-s106806289--ed3b50d7d009964e8fbfb2d0250fc67e.nii.gz
# │       └── func
# │           ├── sub-09_ses-test_task-covertverbgeneration_bold.nii.gz -> ../../../.git/annex/objects/9x/8z/MD5E-s24415813--8c4d3158eda8efb430816469342f2d83.nii.gz/MD5E-s24415813--8c4d3158eda8efb430816469342f2d83.nii.gz
# │           ├── sub-09_ses-test_task-fingerfootlips_bold.nii.gz -> ../../../.git/annex/objects/Pp/J2/MD5E-s25892719--8591a417c483510c6492132b5f0cecb8.nii.gz/MD5E-s25892719--8591a417c483510c6492132b5f0cecb8.nii.gz
# │           ├── sub-09_ses-test_task-linebisection_bold.nii.gz -> ../../../.git/annex/objects/vf/7Z/MD5E-s33605998--6a5422bb4dfded010105d8fd14a3f454.nii.gz/MD5E-s33605998--6a5422bb4dfded010105d8fd14a3f454.nii.gz
# │           ├── sub-09_ses-test_task-linebisection_events.tsv
# │           ├── sub-09_ses-test_task-overtverbgeneration_bold.nii.gz -> ../../../.git/annex/objects/mV/29/MD5E-s12849009--d9afb889bde8c40bc778bff8ba55060b.nii.gz/MD5E-s12849009--d9afb889bde8c40bc778bff8ba55060b.nii.gz
# │           └── sub-09_ses-test_task-overtwordrepetition_bold.nii.gz -> ../../../.git/annex/objects/pk/wX/MD5E-s10859124--729337dd4c06fb3aceae73a91fbd5300.nii.gz/MD5E-s10859124--729337dd4c06fb3aceae73a91fbd5300.nii.gz
# ├── sub-10
# │   ├── ses-retest
# │   │   ├── anat
# │   │   │   └── sub-10_ses-retest_T1w.nii.gz -> ../../../.git/annex/objects/pZ/57/MD5E-s8165420--f72be15a6c60658bac5148423087bb85.nii.gz/MD5E-s8165420--f72be15a6c60658bac5148423087bb85.nii.gz
# │   │   ├── dwi
# │   │   │   └── sub-10_ses-retest_dwi.nii.gz -> ../../../.git/annex/objects/v0/JM/MD5E-s101212223--f7d66db879a83e55b4caa332fb60f0a9.nii.gz/MD5E-s101212223--f7d66db879a83e55b4caa332fb60f0a9.nii.gz
# │   │   └── func
# │   │       ├── sub-10_ses-retest_task-covertverbgeneration_bold.nii.gz -> ../../../.git/annex/objects/kx/8m/MD5E-s22613897--fedb2d74d4c0426bda2660a0194a6e3c.nii.gz/MD5E-s22613897--fedb2d74d4c0426bda2660a0194a6e3c.nii.gz
# │   │       ├── sub-10_ses-retest_task-fingerfootlips_bold.nii.gz -> ../../../.git/annex/objects/4j/Q5/MD5E-s24086519--a813253ad6218481c5ac211a7b70cb2a.nii.gz/MD5E-s24086519--a813253ad6218481c5ac211a7b70cb2a.nii.gz
# │   │       ├── sub-10_ses-retest_task-linebisection_bold.nii.gz -> ../../../.git/annex/objects/0V/7G/MD5E-s31223672--4817426ded5dcaa26ab61206c8c25a01.nii.gz/MD5E-s31223672--4817426ded5dcaa26ab61206c8c25a01.nii.gz
# │   │       ├── sub-10_ses-retest_task-linebisection_events.tsv
# │   │       ├── sub-10_ses-retest_task-overtverbgeneration_bold.nii.gz -> ../../../.git/annex/objects/PK/m9/MD5E-s12012688--f84bcd3565935a28933f3f6ec778b7e4.nii.gz/MD5E-s12012688--f84bcd3565935a28933f3f6ec778b7e4.nii.gz
# │   │       └── sub-10_ses-retest_task-overtwordrepetition_bold.nii.gz -> ../../../.git/annex/objects/wj/XP/MD5E-s10205344--4dae96535f63a91e230ceee0567731cb.nii.gz/MD5E-s10205344--4dae96535f63a91e230ceee0567731cb.nii.gz
# │   └── ses-test
# │       ├── anat
# │       │   └── sub-10_ses-test_T1w.nii.gz -> ../../../.git/annex/objects/Mq/mJ/MD5E-s8625770--9aad310eebc17dfa2a14de13ae26c9a0.nii.gz/MD5E-s8625770--9aad310eebc17dfa2a14de13ae26c9a0.nii.gz
# │       ├── dwi
# │       │   └── sub-10_ses-test_dwi.nii.gz -> ../../../.git/annex/objects/vW/Jp/MD5E-s408320142--0e710fe67a26868893112fdbcf441fe1.nii.gz/MD5E-s408320142--0e710fe67a26868893112fdbcf441fe1.nii.gz
# │       └── func
# │           ├── sub-10_ses-test_task-covertverbgeneration_bold.nii.gz -> ../../../.git/annex/objects/p2/69/MD5E-s23125294--db06785e844b7705bf4eb76c3934e515.nii.gz/MD5E-s23125294--db06785e844b7705bf4eb76c3934e515.nii.gz
# │           ├── sub-10_ses-test_task-fingerfootlips_bold.nii.gz -> ../../../.git/annex/objects/wg/wQ/MD5E-s24873409--ef5680f23a727a842c0259fbd38b8207.nii.gz/MD5E-s24873409--ef5680f23a727a842c0259fbd38b8207.nii.gz
# │           ├── sub-10_ses-test_task-linebisection_bold.nii.gz -> ../../../.git/annex/objects/zP/g6/MD5E-s32217029--be5d868e5a99f7ae36db9965035197ba.nii.gz/MD5E-s32217029--be5d868e5a99f7ae36db9965035197ba.nii.gz
# │           ├── sub-10_ses-test_task-linebisection_events.tsv
# │           ├── sub-10_ses-test_task-overtverbgeneration_bold.nii.gz -> ../../../.git/annex/objects/xZ/3P/MD5E-s12286926--5194547f3ddf306eca340a7e67ae3376.nii.gz/MD5E-s12286926--5194547f3ddf306eca340a7e67ae3376.nii.gz
# │           └── sub-10_ses-test_task-overtwordrepetition_bold.nii.gz -> ../../../.git/annex/objects/9G/VZ/MD5E-s10338205--6cd9153fc2727a337c055c687c8ef705.nii.gz/MD5E-s10338205--6cd9153fc2727a337c055c687c8ef705.nii.gz
# ├── task-covertverbgeneration_bold.json
# ├── task-covertverbgeneration_events.tsv
# ├── task-fingerfootlips_bold.json
# ├── task-fingerfootlips_events.tsv
# ├── task-linebisection_bold.json
# ├── task-overtverbgeneration_bold.json
# ├── task-overtverbgeneration_events.tsv
# ├── task-overtwordrepetition_bold.json
# └── task-overtwordrepetition_events.tsv
#
# 90 directories, 174 files

# %% [markdown]
# ## Querying BIDS datasets

# %% [markdown]
# ### Loading BIDS datasets
# The BIDSLayout instance is a lightweight container for all of the files in the BIDS project directory. It automatically detects any BIDS entities found in the file paths, and allows us to perform simple but relatively powerful queries over the file tree. By default, defined BIDS entities include things like “subject”, “session”, “run”, and “type”.

# %%
from bids.layout import BIDSLayout
layout = BIDSLayout("ds000114")

# %% [markdown]
# ### Querying the ```BIDSLayout``` using ```get```
#
# When a BIDSLayout is initialized, it scans and indexes all files and metadata within the specified root directory.  Once the indexing is complete, you can start exploring the dataset through different types of queries. The main method for this is ```.get()```. If you call ```.get()``` without any arguments, it simply returns a list of all BIDS files in the dataset:

# %%
all_files = layout.get()
print("There are {} files in the layout.".format(len(all_files)))
print("\nThe first 3 files are:")
all_files[:3]
# Out:
# There are 174 files in the layout.
#
# The first 3 files are:
# [<BIDSFile filename='/home/jovyan/Git_repositories/example-notebooks/books/workflows/ds000114/CHANGES'>,
#  <BIDSJSONFile filename='/home/jovyan/Git_repositories/example-notebooks/books/workflows/ds000114/dataset_description.json'>,
#  <BIDSFile filename='/home/jovyan/Git_repositories/example-notebooks/books/workflows/ds000114/dwi.bval'>]

# %% [markdown]
# In this Python list, each elementis a BIDSFile object. If you want to work with just file names, you can simpliy it with:

# %%
layout.get(return_type='filename')[:3]
# Out:
# ['/home/jovyan/Git_repositories/example-notebooks/books/workflows/ds000114/CHANGES',
#  '/home/jovyan/Git_repositories/example-notebooks/books/workflows/ds000114/dataset_description.json',
#  '/home/jovyan/Git_repositories/example-notebooks/books/workflows/ds000114/dwi.bval']

# %% [markdown]
# __Common BIDS Entities:__
#
# The ```.get()```method supports various arguments that let us narrow down the results based on specific criteria. Any BIDS-defined keywords - referred to as entities in PyBIDS - can be used as filters. Here are the most common ones:
#
# ```suffix```: The part of a BIDS filename just before the extension (e.g., 'bold', 'events', 'physio', etc.).
#
# ```subject```: The subject label
#
# ```session```: The session label
#
# ```run```: The run index
#
# ```task```: The task name

# %%
layout.get_entities()
# Out:
# {'subject': <Entity subject (pattern=[/\\]+sub-([a-zA-Z0-9+]+), dtype=<class 'str'>)>,
#  'session': <Entity session (pattern=[_/\\]+ses-([a-zA-Z0-9+]+), dtype=<class 'str'>)>,
#  'sample': <Entity sample (pattern=[_/\\]+sample-([a-zA-Z0-9+]+), dtype=<class 'str'>)>,
#  'task': <Entity task (pattern=[_/\\]+task-([a-zA-Z0-9+]+), dtype=<class 'str'>)>,
#  'tracksys': <Entity tracksys (pattern=[_/\\]+tracksys-([a-zA-Z0-9+]+), dtype=<class 'str'>)>,
#  'acquisition': <Entity acquisition (pattern=[_/\\]+acq-([a-zA-Z0-9+]+), dtype=<class 'str'>)>,
#  'nucleus': <Entity nucleus (pattern=[_/\\]+nuc-([a-zA-Z0-9+]+), dtype=<class 'str'>)>,
#  'volume': <Entity volume (pattern=[_/\\]+voi-([a-zA-Z0-9+]+), dtype=<class 'str'>)>,
#  'ceagent': <Entity ceagent (pattern=[_/\\]+ce-([a-zA-Z0-9+]+), dtype=<class 'str'>)>,
#  'staining': <Entity staining (pattern=[_/\\]+stain-([a-zA-Z0-9+]+), dtype=<class 'str'>)>,
#  'tracer': <Entity tracer (pattern=[_/\\]+trc-([a-zA-Z0-9+]+), dtype=<class 'str'>)>,
#  'reconstruction': <Entity reconstruction (pattern=[_/\\]+rec-([a-zA-Z0-9+]+), dtype=<class 'str'>)>,
#  'direction': <Entity direction (pattern=[_/\\]+dir-([a-zA-Z0-9+]+), dtype=<class 'str'>)>,
#  'run': <Entity run (pattern=[_/\\]+run-(\d+), dtype=<class 'bids.layout.utils.PaddedInt'>)>,
#  'proc': <Entity proc (pattern=[_/\\]+proc-([a-zA-Z0-9+]+), dtype=<class 'str'>)>,
#  'modality': <Entity modality (pattern=[_/\\]+mod-([a-zA-Z0-9+]+), dtype=<class 'str'>)>,
#  'echo': <Entity echo (pattern=[_/\\]+echo-([0-9]+), dtype=<class 'str'>)>,
#  'flip': <Entity flip (pattern=[_/\\]+flip-([0-9]+), dtype=<class 'str'>)>,
#  'inv': <Entity inv (pattern=[_/\\]+inv-([0-9]+), dtype=<class 'str'>)>,
#  'mt': <Entity mt (pattern=[_/\\]+mt-(on|off), dtype=<class 'str'>)>,
#  'part': <Entity part (pattern=[_/\\]+part-(imag|mag|phase|real), dtype=<class 'str'>)>,
#  'recording': <Entity recording (pattern=[_/\\]+recording-([a-zA-Z0-9+]+), dtype=<class 'str'>)>,
#  'space': <Entity space (pattern=[_/\\]+space-([a-zA-Z0-9+]+), dtype=<class 'str'>)>,
#  'chunk': <Entity chunk (pattern=[_/\\]+chunk-([0-9]+), dtype=<class 'str'>)>,
#  'suffix': <Entity suffix (pattern=(?:^|[_/\\])([a-zA-Z0-9+]+)\.[^/\\]+$, dtype=<class 'str'>)>,
#  'scans': <Entity scans (pattern=(.*\_scans.tsv)$, dtype=<class 'str'>)>,
#  'fmap': <Entity fmap (pattern=(phasediff|magnitude[1-2]|phase[1-2]|fieldmap|epi)\.nii, dtype=<class 'str'>)>,
#  'datatype': <Entity datatype (pattern=[/\\]+(anat|beh|dwi|eeg|fmap|func|ieeg|meg|micr|motion|mrs|nirs|perf|pet)[/\\]+, dtype=<class 'str'>)>,
#  'extension': <Entity extension (pattern=[^./\\](\.[^/\\]+)$, dtype=<class 'str'>)>,
#  'EchoTime': <Entity EchoTime (pattern=None, dtype=<class 'str'>)>,
#  'FlipAngle': <Entity FlipAngle (pattern=None, dtype=<class 'str'>)>,
#  'RepetitionTime': <Entity RepetitionTime (pattern=None, dtype=<class 'str'>)>,
#  'SliceTiming': <Entity SliceTiming (pattern=None, dtype=<class 'str'>)>,
#  'TaskName': <Entity TaskName (pattern=None, dtype=<class 'str'>)>}

# %% [markdown]
# *Query by subjects:*

# %%
layout.get_subjects()
# Out:
# ['01', '02', '03', '04', '05', '06', '07', '08', '09', '10']

# %% [markdown]
# *Query by sessions:*

# %%
layout.get_sessions()
# Out:
# ['retest', 'test']

# %% [markdown]
# *Query by tasks:*

# %%
layout.get_task()
# Out:
# ['covertverbgeneration',
#  'fingerfootlips',
#  'linebisection',
#  'overtverbgeneration',
#  'overtwordrepetition']

# %% [markdown]
# Here’s how we would retrieve all BOLD runs with *.nii.gz* extensions for *subject '02'*:

# %%
# Retrieve filenames of all BOLD runs for subject 02
layout.get(subject='02', extension='nii.gz', suffix='bold', return_type='filename')
# Out:
# ['/home/jovyan/Git_repositories/example-notebooks/books/workflows/ds000114/sub-02/ses-retest/func/sub-02_ses-retest_task-covertverbgeneration_bold.nii.gz',
#  '/home/jovyan/Git_repositories/example-notebooks/books/workflows/ds000114/sub-02/ses-retest/func/sub-02_ses-retest_task-fingerfootlips_bold.nii.gz',
#  '/home/jovyan/Git_repositories/example-notebooks/books/workflows/ds000114/sub-02/ses-retest/func/sub-02_ses-retest_task-linebisection_bold.nii.gz',
#  '/home/jovyan/Git_repositories/example-notebooks/books/workflows/ds000114/sub-02/ses-retest/func/sub-02_ses-retest_task-overtverbgeneration_bold.nii.gz',
#  '/home/jovyan/Git_repositories/example-notebooks/books/workflows/ds000114/sub-02/ses-retest/func/sub-02_ses-retest_task-overtwordrepetition_bold.nii.gz',
#  '/home/jovyan/Git_repositories/example-notebooks/books/workflows/ds000114/sub-02/ses-test/func/sub-02_ses-test_task-covertverbgeneration_bold.nii.gz',
#  '/home/jovyan/Git_repositories/example-notebooks/books/workflows/ds000114/sub-02/ses-test/func/sub-02_ses-test_task-fingerfootlips_bold.nii.gz',
#  '/home/jovyan/Git_repositories/example-notebooks/books/workflows/ds000114/sub-02/ses-test/func/sub-02_ses-test_task-linebisection_bold.nii.gz',
#  '/home/jovyan/Git_repositories/example-notebooks/books/workflows/ds000114/sub-02/ses-test/func/sub-02_ses-test_task-overtverbgeneration_bold.nii.gz',
#  '/home/jovyan/Git_repositories/example-notebooks/books/workflows/ds000114/sub-02/ses-test/func/sub-02_ses-test_task-overtwordrepetition_bold.nii.gz']

# %% [markdown]
# ### Extracting metadata
# All the entities mentioned above are derived from the filenames in a BIDS dataset. However, sometimes we want to filter files not just by their names, but also using **metadata** defined in sidecar JSON files, as specified by the BIDS standard. When a BIDSLayout is initialized, it automatically indexes all associated metadata files. This means we can use any key found in a JSON file as a filter in ```.get()```, and we can even combine these with core BIDS entities like subject, run, and task.
#
# For example, suppose we want to retrieve all files that meet the following criteria:
# (a) the RepetitionTime metadata value is 2.5,
# (b) the task is either 'covert_verb_generation' or 'finger_foot_lips', and
# (c) the subject is '01' or '02'.
#
# Here’s how we can do that:

# %%
layout.get(subject=['01', '02'], RepetitionTime=2.5, TaskName=['covert_verb_generation', 'finger_foot_lips'] )
# Out:
# [<BIDSImageFile filename='/home/jovyan/Git_repositories/example-notebooks/books/workflows/ds000114/sub-01/ses-retest/func/sub-01_ses-retest_task-covertverbgeneration_bold.nii.gz'>,
#  <BIDSImageFile filename='/home/jovyan/Git_repositories/example-notebooks/books/workflows/ds000114/sub-01/ses-retest/func/sub-01_ses-retest_task-fingerfootlips_bold.nii.gz'>,
#  <BIDSImageFile filename='/home/jovyan/Git_repositories/example-notebooks/books/workflows/ds000114/sub-01/ses-test/func/sub-01_ses-test_task-covertverbgeneration_bold.nii.gz'>,
#  <BIDSImageFile filename='/home/jovyan/Git_repositories/example-notebooks/books/workflows/ds000114/sub-01/ses-test/func/sub-01_ses-test_task-fingerfootlips_bold.nii.gz'>,
#  <BIDSImageFile filename='/home/jovyan/Git_repositories/example-notebooks/books/workflows/ds000114/sub-02/ses-retest/func/sub-02_ses-retest_task-covertverbgeneration_bold.nii.gz'>,
#  <BIDSImageFile filename='/home/jovyan/Git_repositories/example-notebooks/books/workflows/ds000114/sub-02/ses-retest/func/sub-02_ses-retest_task-fingerfootlips_bold.nii.gz'>,
#  <BIDSImageFile filename='/home/jovyan/Git_repositories/example-notebooks/books/workflows/ds000114/sub-02/ses-test/func/sub-02_ses-test_task-covertverbgeneration_bold.nii.gz'>,
#  <BIDSImageFile filename='/home/jovyan/Git_repositories/example-notebooks/books/workflows/ds000114/sub-02/ses-test/func/sub-02_ses-test_task-fingerfootlips_bold.nii.gz'>]

# %% [markdown]
# ## The ```BIDSFile```
#
# Calling ```.get()``` on a ```BIDSLayout``` returns a list of ```BIDSFile``` objects by default. These are lightweight representations of individual files within a BIDS dataset and offer convenient access to various attributes and methods. Let’s explore what a ```BIDSFile``` can do. To start, we’ll select a random file from the layout.

# %%
# Pick the 11th file in the dataset
bf = layout.get()[11]

# Print it
bf
# Out:
# <BIDSImageFile filename='/home/jovyan/Git_repositories/example-notebooks/books/workflows/ds000114/sub-01/ses-retest/func/sub-01_ses-retest_task-overtverbgeneration_bold.nii.gz'>

# %% [markdown]
# A ```BIDSFile``` provides a convenient interface to interact with individual files in a BIDS dataset. Depending on the file type, different attributes and methods are available. Keep in mind that some methods are only applicable to specific types of files—for example, you can’t use ```.get_image()``` on a non-image file.
#
# Here are some commonly used attributes and methods:
#
# ```.path``` – Full path to the file
#
# ```.filename``` – Name of the file (excluding the directory)
#
# ```.dirname``` – Directory where the file is located
#
# ```.get_entities()``` – Returns a dictionary of entities (e.g., subject, task) associated with the file; metadata can be optionally included
#
# ```.get_image()``` – Loads the file as a nibabel image (only valid for image files)
#
# ```.get_df()``` – Loads the file into a pandas DataFrame (works for .tsv files)
#
# ```.get_metadata()``` – Retrieves a dictionary of metadata from the related JSON sidecar(s)
#
# ```.get_associations()``` – Lists other files that are linked to this one (e.g., JSON, events, or anatomical associations)

# %%
# Print all the entities associated with this file, and their values
bf.get_entities()
# Out:
# {'datatype': 'func',
#  'extension': '.nii.gz',
#  'session': 'retest',
#  'subject': '01',
#  'suffix': 'bold',
#  'task': 'overtverbgeneration'}

# %%
# Print all metadata of this file
bf.get_metadata()
# Out:
# {'EchoTime': 0.05,
#  'FlipAngle': 90,
#  'RepetitionTime': 5.0,
#  'SliceTiming': [0.0,
#   1.2499999999999998,
#   0.08333333333333333,
#   1.333333333333333,
#   0.16666666666666666,
#   1.4166666666666663,
#   0.25,
#   1.4999999999999996,
#   0.3333333333333333,
#   1.5833333333333328,
#   0.41666666666666663,
#   1.666666666666666,
#   0.5,
#   1.7499999999999993,
#   0.5833333333333333,
#   1.8333333333333326,
#   0.6666666666666666,
#   1.9166666666666659,
#   0.75,
#   1.9999999999999991,
#   0.8333333333333333,
#   2.083333333333332,
#   0.9166666666666666,
#   2.1666666666666656,
#   1.0,
#   2.249999999999999,
#   1.0833333333333333,
#   2.333333333333332,
#   1.1666666666666665,
#   2.416666666666665],
#  'TaskName': 'overt_verb_generation'}

# %%
# Get union of both of the above in one shot like this
bf.get_entities(metadata='all')
# Out:
# {'EchoTime': 0.05,
#  'FlipAngle': 90,
#  'RepetitionTime': 5.0,
#  'SliceTiming': [0.0,
#   1.2499999999999998,
#   0.08333333333333333,
#   1.333333333333333,
#   0.16666666666666666,
#   1.4166666666666663,
#   0.25,
#   1.4999999999999996,
#   0.3333333333333333,
#   1.5833333333333328,
#   0.41666666666666663,
#   1.666666666666666,
#   0.5,
#   1.7499999999999993,
#   0.5833333333333333,
#   1.8333333333333326,
#   0.6666666666666666,
#   1.9166666666666659,
#   0.75,
#   1.9999999999999991,
#   0.8333333333333333,
#   2.083333333333332,
#   0.9166666666666666,
#   2.1666666666666656,
#   1.0,
#   2.249999999999999,
#   1.0833333333333333,
#   2.333333333333332,
#   1.1666666666666665,
#   2.416666666666665],
#  'TaskName': 'overt_verb_generation',
#  'datatype': 'func',
#  'extension': '.nii.gz',
#  'session': 'retest',
#  'subject': '01',
#  'suffix': 'bold',
#  'task': 'overtverbgeneration'}

# %%
# Here are all the files associated with our target file in some way
bf.get_associations()
# Out:
# [<BIDSJSONFile filename='/home/jovyan/Git_repositories/example-notebooks/books/workflows/ds000114/task-overtverbgeneration_bold.json'>]

# %% [markdown]
# ### Exporting a BIDSLayout to a pandas Dataframe
# If you’re looking for a high-level overview of all the files in your BIDSLayout without manually iterating through each ```BIDSFile``` and extracting their entities, the ```.to_df()``` method offers a convenient solution. It provides a structured summary of the dataset in the form of a pandas DataFrame.

# %%
# Convert the layout to a pandas dataframe
df = layout.to_df()
df.head()
# Out:
# entity                                               path datatype extension  \
# 0       /home/jovyan/Git_repositories/example-notebook...      NaN     .json
# 1       /home/jovyan/Git_repositories/example-notebook...      NaN     .bval
# 2       /home/jovyan/Git_repositories/example-notebook...      NaN     .bvec
# 3       /home/jovyan/Git_repositories/example-notebook...      NaN      .tsv
# 4       /home/jovyan/Git_repositories/example-notebook...     anat   .nii.gz
#
# entity session subject        suffix task
# 0          NaN     NaN   description  NaN
# 1          NaN     NaN           dwi  NaN
# 2          NaN     NaN           dwi  NaN
# 3          NaN     NaN  participants  NaN
# 4       retest      01           T1w  NaN

# %%
# Include metadata
layout.to_df(metadata=True).head(10)
# Out:
# entity                                               path EchoTime FlipAngle  \
# 0       /home/jovyan/Git_repositories/example-notebook...      NaN       NaN
# 1       /home/jovyan/Git_repositories/example-notebook...      NaN       NaN
# 2       /home/jovyan/Git_repositories/example-notebook...      NaN       NaN
# 3       /home/jovyan/Git_repositories/example-notebook...      NaN       NaN
# 4       /home/jovyan/Git_repositories/example-notebook...      NaN       NaN
# 5       /home/jovyan/Git_repositories/example-notebook...      NaN       NaN
# 6       /home/jovyan/Git_repositories/example-notebook...     0.05        90
# 7       /home/jovyan/Git_repositories/example-notebook...     0.05        90
# 8       /home/jovyan/Git_repositories/example-notebook...     0.05        90
# 9       /home/jovyan/Git_repositories/example-notebook...      NaN       NaN
#
# entity RepetitionTime                                        SliceTiming  \
# 0                 NaN                                                NaN
# 1                 NaN                                                NaN
# 2                 NaN                                                NaN
# 3                 NaN                                                NaN
# 4                 NaN                                                NaN
# 5                 NaN                                                NaN
# 6                 2.5  [0.0, 1.2499999999999998, 0.08333333333333333,...
# 7                 2.5  [0.0, 1.2499999999999998, 0.08333333333333333,...
# 8                 2.5  [0.0, 1.2499999999999998, 0.08333333333333333,...
# 9                 NaN                                                NaN
#
# entity                TaskName datatype extension session subject  \
# 0                          NaN      NaN     .json     NaN     NaN
# 1                          NaN      NaN     .bval     NaN     NaN
# 2                          NaN      NaN     .bvec     NaN     NaN
# 3                          NaN      NaN      .tsv     NaN     NaN
# 4                          NaN     anat   .nii.gz  retest      01
# 5                          NaN      dwi   .nii.gz  retest      01
# 6       covert_verb_generation     func   .nii.gz  retest      01
# 7             finger_foot_lips     func   .nii.gz  retest      01
# 8               line_bisection     func   .nii.gz  retest      01
# 9                          NaN     func      .tsv  retest      01
#
# entity        suffix                  task
# 0        description                   NaN
# 1                dwi                   NaN
# 2                dwi                   NaN
# 3       participants                   NaN
# 4                T1w                   NaN
# 5                dwi                   NaN
# 6               bold  covertverbgeneration
# 7               bold        fingerfootlips
# 8               bold         linebisection
# 9             events         linebisection

# %% [markdown]
# ## BIDS Validator
# ```PyBIDS``` includes an implicit import of the ```BIDSValidator``` class from the separate ```bids-validator``` package. This class can be used to check whether a given file path conforms to BIDS naming conventions and to infer what type of data the file represents.
#
# However, it's important to note that the Python-based validator may lag behind the official JavaScript implementation available online. Additionally, the Python version only validates individual file paths - it doesn't support validation of an entire ```BIDS dataset```. For full dataset validation, it's recommended to use the online [BIDS Validator](https://bids-standard.github.io/bids-validator/).

# %%
from bids.layout import BIDSValidator

# %%
# When using the bids validator, the filepath MUST be relative to the top level bids directory
validator = BIDSValidator()
validator.is_bids('/sub-02/ses-retest/func/sub-02_ses-retest_task-covertverbgeneration_bold.nii.gz')
# Out:
# True

# %%
# Can decide if a filepath represents a file part of the specification
validator.is_file('/sub-02/ses-retest/func/sub-02_ses-retest_task-covertverbgeneration_bold.nii.gz')
# Out:
# True

# %%
# Can check if a file is at the top level of the dataset
validator.is_top_level('/dataset_description.json')
# Out:
# True

# %%
# or subject (or session) level
validator.is_subject_level('/dataset_description.json')
# Out:
# False

# %%
# Can decide if a filepath represents phenotypic data
validator.is_phenotypic('/sub-02/ses-test/anat/sub-02_ses-test_T1w.nii.gz')
# Out:
# False

# %% [markdown]
# #### Dependencies in Jupyter/Python
# - Using the package [watermark](https://github.com/rasbt/watermark) to document system environment and software versions used in this notebook

# %%
# %load_ext watermark

# %watermark
# %watermark --iversions
# Out:
# Last updated: 2025-10-30T23:38:55.548583+00:00
#
# Python implementation: CPython
# Python version       : 3.11.6
# IPython version      : 8.16.1
#
# Compiler    : GCC 12.3.0
# OS          : Linux
# Release     : 5.4.0-204-generic
# Machine     : x86_64
# Processor   : x86_64
# CPU cores   : 32
# Architecture: 64bit
#
# bids_validator: 1.14.7.post0
# bids          : 0.21.0
